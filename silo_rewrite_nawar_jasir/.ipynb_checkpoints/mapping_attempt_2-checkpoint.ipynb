# %%
import pandas as pd

df = pd.read_csv("another_try.csv")
df.head()
# Out:
#                                           Unnamed: 0
# 0  Hunan Clinical Research Center of Ophthalmic D...
# 1         Biomedecine Agency, Saint Denis La Plaine.
# 2  Project Management Department, Sanwa Kagaku Ke...
# 3  Translational Research Institute, Brisbane, Au...
# 4  Pediatric Nephrology, State University of Camp...

# %%
usa_filter = r"\b(?:Alabama|AL|Alaska|AK|Arizona|AZ|Arkansas|AR|California|CA|Colorado|CO|Connecticut|CT|Delaware|DE|Florida|FL|Georgia|GA|Hawaii|HI|Idaho|ID|Illinois|]IL|Indiana|IN|Iowa|IA|Kansas|KS|Kentucky|KY|Louisiana|LA|Maine|ME|Maryland|MD|Massachusetts|MA|Michigan|MI|Minnesota|MN|Mississippi|MS|Missouri|MO|Montana|MT|Nevada|NV|New\s+Hampshire|NH|New\s+Jersey|NJ|New\s+Mexico|NM|New\s+York|NY|North\s+Carolina|NC|North\s+Dakota|ND|Ohio|OH|Oklahoma|OK|Oregon|OR|Pennsylvania|PA|Rhode\s+Island|RI|South\s+Carolina|SC|South\s+Dakota|SD|Tennessee|TN|Texas|TX|Utah|UT|Vermont|VT|Virginia|VA|Washington|WA|West\s+Virginia|WV|Wisconsin|WI|Wyoming|WY|Nebraska|NE|USA|Boston|Irving|Stanford|San\s+Francisco|Tennesse)\b"
usa = df[df['Unnamed: 0'].str.contains(usa_filter,regex=True,na=False)]
the_rest = df.loc[~ df['Unnamed: 0'].isin(list(usa['Unnamed: 0']))]

# %%
canada_filter = r"\b(?:Canada|British\s+Columbia|Manitoba|Toronto|Quebec|Hamilton|Ontario|Calgary)\b"
canada = the_rest[the_rest['Unnamed: 0'].str.contains(canada_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(canada['Unnamed: 0']))]

# %%
france_filter = r"\b(?:France|Limoges|Strasbourg|Saint\s+Denis\s+La\s+Plaine|Paris|Amiens|Lyon|Nantes|Bordeaux|Lille|CHU|Montpellier)\b"
france = the_rest[the_rest['Unnamed: 0'].str.contains(france_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(france['Unnamed: 0']))]

# %%
china_filter = r"\b(?:China|Hong\s+Kong|Beijing|Nanfang|Shenzhen|Huizhou|Shanghai|Guangzhou|Hangzhou|Zhejiang)\b"
china = the_rest[the_rest['Unnamed: 0'].str.contains(china_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(china['Unnamed: 0']))]

# %%
uk_filter = r"\b(?:UK|United\s+Kingdom|Sheffield|London|Leeds|Liverpool|Bristol|Leicester|Nottingham|Cambridge)\b"
uk = the_rest[the_rest['Unnamed: 0'].str.contains(uk_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(uk['Unnamed: 0']))]

# %%
germany_filter = r"\b(?:Germany)\b"
germany = the_rest[the_rest['Unnamed: 0'].str.contains(germany_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(germany['Unnamed: 0']))]

# %%
brussels_filter = r"\b(?:Belgium|Leuven)\b"
brussels = the_rest[the_rest['Unnamed: 0'].str.contains(brussels_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(brussels['Unnamed: 0']))]

# %%
nether_filter = r"\b(?:Netherlands|Leiden|Groningen)\b"
nether = the_rest[the_rest['Unnamed: 0'].str.contains(nether_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(nether['Unnamed: 0']))]

# %%
australia_filter = r"\b(?:Australia|Wales|Queensland|Herston|Woolloongabba|Sydney)\b"
australia = the_rest[the_rest['Unnamed: 0'].str.contains(australia_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(australia['Unnamed: 0']))]

# %%
italy_filter = r"\b(?:Italy|Bologna)\b"
italy = the_rest[the_rest['Unnamed: 0'].str.contains(italy_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(italy['Unnamed: 0']))]

# %%
spain_filter = r"\b(?:Spain)\b"
spain = the_rest[the_rest['Unnamed: 0'].str.contains(spain_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(spain['Unnamed: 0']))]

# %%
india_filter = r"\b(?:India)\b"
india = the_rest[the_rest['Unnamed: 0'].str.contains(india_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(india['Unnamed: 0']))]

# %%
japan_filter = r"\b(?:Japan)\b"
japan = the_rest[the_rest['Unnamed: 0'].str.contains(japan_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(japan['Unnamed: 0']))]

# %%
israel_filter = r"\b(?:Israel|Tel-Aviv)\b"
israel = the_rest[the_rest['Unnamed: 0'].str.contains(israel_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(israel['Unnamed: 0']))]

# %%
sweden_filter = r"\b(?:Sweden)\b"
sweden = the_rest[the_rest['Unnamed: 0'].str.contains(sweden_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(sweden['Unnamed: 0']))]

# %%
brazil_filter = r"\b(?:Brazil)\b"
brazil = the_rest[the_rest['Unnamed: 0'].str.contains(brazil_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(brazil['Unnamed: 0']))]

# %%
taiwan_filter = r"\b(?:Taiwan)\b"
taiwan = the_rest[the_rest['Unnamed: 0'].str.contains(taiwan_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(taiwan['Unnamed: 0']))]

# %%
denmark_filter = r"\b(?:Denmark|Copenhagen)\b"
denmark = the_rest[the_rest['Unnamed: 0'].str.contains(denmark_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(denmark['Unnamed: 0']))]

# %%
korea_filter = r"\b(?:Korea|Seoul)\b"
korea = the_rest[the_rest['Unnamed: 0'].str.contains(korea_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(korea['Unnamed: 0']))]

# %%
swiss_filter = r"\b(?:Switzerland|Zurich)\b"
swiss = the_rest[the_rest['Unnamed: 0'].str.contains(swiss_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(swiss['Unnamed: 0']))]

# %%
austria_filter = r"\b(?:Austria)\b"
austria = the_rest[the_rest['Unnamed: 0'].str.contains(austria_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(austria['Unnamed: 0']))]

# %%
nz_filter = r"\b(?:New\s+Zealand|Auckland)\b"
nz = the_rest[the_rest['Unnamed: 0'].str.contains(nz_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(nz['Unnamed: 0']))]

# %%
mex_filter = r"\b(?:Mexico)\b"
mex = the_rest[the_rest['Unnamed: 0'].str.contains(mex_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(mex['Unnamed: 0']))]

# %%
pol_filter = r"\b(?:Poland)\b"
pol = the_rest[the_rest['Unnamed: 0'].str.contains(pol_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(pol['Unnamed: 0']))]

# %%
mid_filter = r"\b(?:Turkey|Jordan|Iran|Saudi\s+Arabia|Abu\s+Dhabi|Dubai|Qatar|Riyadh|Doha)\b"
mid = the_rest[the_rest['Unnamed: 0'].str.contains(mid_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(mid['Unnamed: 0']))]

# %%
argen_filter = r"\b(?:Argentina)\b"
argen = the_rest[the_rest['Unnamed: 0'].str.contains(argen_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(argen['Unnamed: 0']))]

# %%
sing_filter = r"\b(?:Singapore)\b"
sing = the_rest[the_rest['Unnamed: 0'].str.contains(sing_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(sing['Unnamed: 0']))]

# %%
czech_filter = r"\b(?:Czech\s+Republic|Czechia|Prague)\b"
czech = the_rest[the_rest['Unnamed: 0'].str.contains(czech_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(czech['Unnamed: 0']))]

# %%
irish_filter = r"\b(?:Ireland|Scotland|Dublin)\b"
irish = the_rest[the_rest['Unnamed: 0'].str.contains(irish_filter,regex=True,na=False)]
the_rest = the_rest.loc[~ the_rest['Unnamed: 0'].isin(list(irish['Unnamed: 0']))]

# %%
usa["PARENT"] = ""
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/1744949602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa["PARENT"] = ""

# %%
us_unis = list(pd.read_csv('us_universities.csv')['name'])
us_unis
# Out:
# ['Abilene Christian University',
#  'Academy of Art College',
#  'Adams State College',
#  'Adelphi University',
#  'Adler School of Professional Psychology',
#  'Adrian College',
#  'Agnes Scott College',
#  'Air Force Institute of Technology',
#  'Alabama Agricultural and Mechanical University',
#  'Alabama State University',
#  'Alaska Bible College',
#  'Alaska Pacific University',
#  'Albany College of Pharmacy',
#  'Albany Law School',
#  'Albany Medical Center',
#  'Albany State University',
#  'Albertus Magnus College',
#  'Albion College',
#  'Albright College',
#  'Alcorn State University',
#  'Alderson Broaddus College',
#  'Alfred Adler Graduate School',
#  'Alfred University',
#  'Alice Lloyd College',
#  'Allegheny College',
#  'Allen University',
#  'Alma College',
#  'Alvernia College',
#  'Alverno College',
#  'Ambassador University',
#  'Amber University',
#  'American Academy of Nutrition',
#  'American Business & Technology University',
# ...

# %%
for uni in us_unis:
    usa.loc[usa['Unnamed: 0'].str.contains(uni), 'PARENT'] = uni + "]US"
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/804935128.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   usa.loc[usa['Unnamed: 0'].str.contains(uni), 'PARENT'] = uni + "]US"

# %%
def mapper(df, search, case, parent):
    df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
usa.loc[usa['Unnamed: 0'].str.contains("Cornell"), 'PARENT'] = "Cornell University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Harvard"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Yale"), 'PARENT'] = "Yale University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("NYU"), 'PARENT'] = "New York University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("New York Uni"), 'PARENT'] = "New York University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Massachusetts General Hospital"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Brigham and Women's Hospital"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Brigham & Women's Hospital"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Dana-Farber"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Beth Israel Deaconess"), 'PARENT'] = "Tufts University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Jean Mayer Human Nutrition Research Center on Aging"), 'PARENT'] = "Tufts University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Tufts"), 'PARENT'] = "Tufts University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("William B. Schwartz"), 'PARENT'] = "Tufts University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Joslin Diabetes"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Boston Children's"), 'PARENT'] = "Harvard University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Boston Medical Center"), 'PARENT'] = "Boston University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA\s+\w+\s+Healthcare"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Mayo Clinic"), 'PARENT'] = "Mayo Clinic"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Johns Hopkins"), 'PARENT'] = "Johns Hopkins University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("John Hopkins"), 'PARENT'] = "Johns Hopkins University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Cleveland Clinic"), 'PARENT'] = "Case Western Reserve University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("UC"), 'PARENT'] = "University of California"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Cedars-Sinai"), 'PARENT'] = "University of California"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Mount Sinai"), 'PARENT'] = "Mount Sinai"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Washington University School of Medicine, St"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Washington University in St"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Washington University, St. Louis"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Washington University, Saint Louis"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Washington University St. Louis"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Stony Brook"), 'PARENT'] = "State University of New York"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("SUNY"), 'PARENT'] = "State University of New York"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Albert Einstein College of Medicine"), 'PARENT'] = "Albert Einstein College of Medicine"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Montefiore"), 'PARENT'] = "Albert Einstein College of Medicine"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("UPMC"), 'PARENT'] = "University of Pittsburgh"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Penn State"), 'PARENT'] = "Pennsylvania State University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's Hospital of Philadelphia"), 'PARENT'] = "University of Pennsylvania"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's Hospital of Pennsylvania"), 'PARENT'] = "University of Pennsylvania"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Perelman School of Medicine"), 'PARENT'] = "University of Pennsylvania"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Geisinger"), 'PARENT'] = "Geisinger Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Kidney Health Research Institute"), 'PARENT'] = "Geisinger Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Rogosin Institute"), 'PARENT'] = "Cornell University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("State University of New York"), 'PARENT'] = "State University of New York"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Mt. Sinai"), 'PARENT'] = "Mount Sinai"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("UT "), 'PARENT'] = "University of Texas"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Texas Heart Institute"), 'PARENT'] = "Texas Heart Institute"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Michael E. DeBakey"), 'PARENT'] = "Baylor College of Medicine"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Houston Methodist"), 'PARENT'] = "Cornell University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Baylor Scott & White"), 'PARENT'] = "Baylor Scott & White Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Baylor Scott and White"), 'PARENT'] = "Baylor Scott & White Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Inova"), 'PARENT'] = "University of Virginia"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("AMGA"), 'PARENT'] = "AMGA"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("UNC"), 'PARENT'] = "University of North Carolina"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Duke"), 'PARENT'] = "Duke University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Wake Forest"), 'PARENT'] = "Wake Forest University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Veterans"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Medical"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Health"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Palo"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA New"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Eastern"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Tennessee"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA Hospital"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VA St. Louis"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Veteran Healthcare"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Valley Health"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Seattle Children"), 'PARENT'] = "University of Washington"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Fred Hutchinson"), 'PARENT'] = "Fred Hutchinson"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Accenture"), 'PARENT'] = "Accenture"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Novo Nordisk"), 'PARENT'] = "Novo Nordisk"+"]DK"
usa.loc[usa['Unnamed: 0'].str.contains("American Society of Nephrology"), 'PARENT'] = "American Society of Nephrology"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Puget Sound Kidney Centers"), 'PARENT'] = "Puget Sound Kidney Centers"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Center for Disease Dynamics, Economics & Policy,"), 'PARENT'] = "One Health Trust"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Medstar Georgetown"), 'PARENT'] = "Georgetown University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's National"), 'PARENT'] = "George Washington University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Bloodworks Northwest"), 'PARENT'] = "Bloodworks Northwest"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Association of American Medical Colleges"), 'PARENT'] = "Association of American Medical Colleges"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Northwest Kidney Centers"), 'PARENT'] = "Northwest Kidney Centers"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("VHA"), 'PARENT'] = "VA Health Systems Research"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Keck"), 'PARENT'] = "University of Southern California"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Kaiser"), 'PARENT'] = "Kaiser Permanente"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Stanford"), 'PARENT'] = "Stanford University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Huntington Medical"), 'PARENT'] = "Huntington Medical"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("California Department of Public Health"), 'PARENT'] = "California Health and Human Services Agency"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Naval Medical"), 'PARENT'] = "United States Navy"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's Hospital Los Angeles"), 'PARENT'] = "University of Southern California"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Henry Ford"), 'PARENT'] = "Henry Ford Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("National Institutes of Health"), 'PARENT'] = "National Institutes of Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("National Institute of"), 'PARENT'] = "National Institutes of Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Robert Wood Johnson"), 'PARENT'] = "Rutgers University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("NewYork-Pres"), 'PARENT'] = "Cornell University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Barnes"), 'PARENT'] = "Washington University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Nationwide Children's Hospital"), 'PARENT'] = "Ohio State University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Vanderbilt"), 'PARENT'] = "Vanderbilt University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Saint Louis University"), 'PARENT'] = "Saint Louis University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Cleveland Medical Center"), 'PARENT'] = "Case Western Reserve University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Cincinnati Children's Hospital"), 'PARENT'] = "University of Cincinnati"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's Mercy"), 'PARENT'] = "University of Kansas"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("St. Louis Children's"), 'PARENT'] = "Washington University in St. Louis"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Food and Drug Administration"), 'PARENT'] = "Department of Health and Human Services"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("New York State Department of Health"), 'PARENT'] = "New York State Department of Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Colorado Center for Transplantation Care"), 'PARENT'] = "University of Colorado"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("DaVita", case=False), 'PARENT'] = "DaVita Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Denver Health"), 'PARENT'] = "University of Colorado"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Centura Transplant"), 'PARENT'] = "Centura Transplant"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Colorado Department of Public Health & Environment"), 'PARENT'] = "Colorado Department of Public Health & Environment"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Colorado University School of Public Health"), 'PARENT'] = "University of Colorado"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Presbyterian/St. Luke's"), 'PARENT'] = "Prebyterian/St. Luke's Medical Center"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Laboratory Corporation of America"), 'PARENT'] = "Labcorp Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Labcorp"), 'PARENT'] = "Labcorp Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("IBM"), 'PARENT'] = "IBM"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Dartmouth"), 'PARENT'] = "Dartmouth College"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Baylor Simmons"), 'PARENT'] = "Baylor Scott & White Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Bayer"), 'PARENT'] = "Bayer Inc"+"]Germany"
usa.loc[usa['Unnamed: 0'].str.contains("CSL"), 'PARENT'] = "CSL Ltd"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Janssen"), 'PARENT'] = "Johnson & Johnson Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Hennepin Health"), 'PARENT'] = "University of Minnesota"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Children's of Alabama"), 'PARENT'] = "University of Alabama"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Otsuka"), 'PARENT'] = "Otsuka Inc"+"]JP"
usa.loc[usa['Unnamed: 0'].str.contains("National Cancer Institute"), 'PARENT'] = "National Institutes of Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("National Heart, Lung and Blood"), 'PARENT'] = "National Institutes of Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("American Association of Kidney Patients"), 'PARENT'] = "American Association of Kidney Patients"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("GRAfT"), 'PARENT'] = "GRAfT"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("AstraZeneca", case=False), 'PARENT'] = "AstraZeneca Inc"+"]GB"
usa.loc[usa['Unnamed: 0'].str.contains("Travere", case=False), 'PARENT'] = "Travere Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Maze", case=False), 'PARENT'] = "Maze Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Cerevel", case=False), 'PARENT'] = "Cerevel Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Nephrology Associates of Northern Illinois and Indiana", case=False), 'PARENT'] = "Nephrology Associates of Northern Illinois and Indiana"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Research on Ethics, Aging, and Community Health", case=False), 'PARENT'] = "Tufts University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Heersink", case=False), 'PARENT'] = "Univeristy of Alabama"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Memorial Sloan", case=False), 'PARENT'] = "Memorial Sloan Kettering"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("GlaxoSmithKline", case=False), 'PARENT'] = "GlaxoSmithKline Inc"+"]GB"
usa.loc[usa['Unnamed: 0'].str.contains("U.?S.? Renal Care", case=False), 'PARENT'] = "US Renal Care"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Regenstrief", case=False), 'PARENT'] = "Regenstrief"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Genentech", case=False), 'PARENT'] = "Genentech Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("RWJ", case=False), 'PARENT'] = "Rutgers University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Natera", case=False), 'PARENT'] = "Natera Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Rho", case=False), 'PARENT'] = "Rho"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Regeneron", case=False), 'PARENT'] = "Regeneron Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Nephrology Associates, PC", case=False), 'PARENT'] = "Nephrology Associates"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Renal Research Institute", case=False), 'PARENT'] = "Renal Research Institute"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Tulane", case=False), 'PARENT'] = "Tulane University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Revivicor", case=False), 'PARENT'] = "Revivicor Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Oregon Health and Science", case=False), 'PARENT'] = "Oregon Health and Science University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Oregon Health & Science", case=False), 'PARENT'] = "Oregon Health and Science University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("ATK", case=False), 'PARENT'] = "ATK Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Pfizer", case=False), 'PARENT'] = "Pfizer Inc"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Ann Arbor", case=False), 'PARENT'] = "University of Michigan"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Feinstein Institute", case=False), 'PARENT'] = "Northwell Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Northwell", case=False), 'PARENT'] = "Northwell Health"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Atrium Health", case=False), 'PARENT'] = "University of North Carolina"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("United Network for Organ Sharing", case=False), 'PARENT'] = "United Network for Organ Sharing"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Loyola", case=False), 'PARENT'] = "Loyola University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Center for Disease Control and Prevention", case=False), 'PARENT'] = "CDC"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("CDC"), 'PARENT'] = "CDC"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Emory"), 'PARENT'] = "Emory University"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Northwestern"), 'PARENT'] = "Northwestern Univerisity"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Vector Psychometric"), 'PARENT'] = "Vector Psychometric Group LLC"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Eagle Health Analytics"), 'PARENT'] = "Eagle Health Analytics LLC"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Positive Rhetoric"), 'PARENT'] = "Positive Rhetoric LLC"+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("REACH/Dialysis", case=False), 'PARENT'] = "REACH/Dialysis Clinic, Inc."+"]US"
usa.loc[usa['Unnamed: 0'].str.contains("Fresenius", case=False), 'PARENT'] = "Fresenius Health"+"]US"
mapper(usa, "Scripps", False, "Scripps Health Inc"+"]US")
mapper(usa, "New York Blood Center",False,"New York Blood Center Enterprises"+"]US")
mapper(usa, "National Kidney Found",False,"National Kidney Foundation"+"]US")
mapper(usa, "Charles River Lab",False,"Charles River Laboratories Inc"+"]US")
mapper(usa, "Children's Minnesota",False,"Children's Minnesota"+"]US")
mapper(usa, "Satellite",False,"Satellite Healthcare"+"]US")
mapper(usa, "Critical Path",False,"Critical Path Institute"+"]US")
mapper(usa, "Ascend",False, "Ascend Clinical Labs Inc"+"]US")
mapper(usa, "Scientific Registry",False,"Scientific Registry of Transplant Recipients"+"]US")
mapper(usa, "Health Equity Outcomes",False,"Health Equity Outcomes Inc"+"]US")
mapper(usa, "Texas Children's",False,"Baylor College of Medicine"+"]US")
mapper(usa, "Atlantic Dialysis Manage",False,"Atlantic Dialysis Management Services Inc"+"]US")
mapper(usa, "Providence", False, "Providence Health Inc"+"]US")
mapper(usa, "One Lambda",False,"Thermo Fisher Inc"+"]US")
mapper(usa, "Metabolon",False,"Metabolon Inc"+"]US")
mapper(usa, "Roswell Park",False,"State University of New York"+"]US")
mapper(usa, "Renal Associates P.",False,"Renal Associates P.A."+"]US")
mapper(usa, 'Maine Medical',False,"Tufts University"+"]US")
mapper(usa, "Erie County Medical",False,"State University of New York"+"]US")
mapper(usa, "Federation Bio",False,"Federation Bio Inc"+"]US")
mapper(usa, "New Mexico Department of Health", False,"New Mexico Department of Health"+"]US")
mapper(usa, "Levine Children's",False,"Wake Forest University"+"]US")
mapper(usa, "Cooperman Barnabas",False,"Rutgers University"+"]US")
mapper(usa, "Allegheny General",False,"Drexel University"+"]US")
mapper(usa, "LSU",False,"Louisiana State University"+"]US")
mapper(usa, "Integris",False,"Integris Health Inc"+"]US")
mapper(usa, "Baptist Health System",False,"Tenet Health Inc"+"]US")
mapper(usa, "Jacobi Medical",False,"Montefiore"+"]US")
mapper(usa, "Rowan-Virtua",False,"Rowan University"+"]US")
mapper(usa, "Nemours Children's",False,"Thomas Jefferson University"+"]US")
mapper(usa, "Helen DeVos Children's",False,"Michigan State University"+"]US")
mapper(usa, "Alport Syndrome Foundation",False,'Alport Syndrome Foundation'+"]US")
mapper(usa, "Children's Healthcare of Atlanta",False,"Emory University"+"]US")
mapper(usa, "Westat",False,"Westat Inc"+"]US")
mapper(usa, "Elemental Scientific",False,"Elemental Scientific Inc"+"]US")
mapper(usa,"Intermountain",False,"Intermountain Health Inc"+"]US")
mapper(usa,"Maryland Department of Health",False,"Maryland Department of Health"+"]US")
mapper(usa,"AZ Klina",False,"AZ Klina"+"]BE")
mapper(usa,"Oklahoma Medical Research",False,"Oklahoma Medical Research Foundation"+"]US")
mapper(usa,"Kootenai Health",False,"Kootenai Health"+"]US")
mapper(usa,"Sanofi",False,"Sanofi Inc"+"]France")
mapper(usa,"Pennsylvania Department of Health",False,"Pennsylvania Department of Health"+"]US")
mapper(usa,"Dallas Nephrology",False,"Dallas Nephrology Associates"+"]US")
mapper(usa,"Women's Health Service Line",False,"Women's Health Service Line"+"]US")
mapper(usa,"Beckman Coulter",False,"Beckman Coulter Inc"+"]US")
mapper(usa,"Morehouse Medical",False,"Morehouse Medical School"+"]US")
mapper(usa,"Health Systems Management",False,"Health Systems Management Inc"+"]US")
mapper(usa,"Akron Children's",False,"University System of Ohio"+"]US")
mapper(usa,"Institute for Clinical Research and Health Policy Studies",False,"Tufts University"+"]US")
mapper(usa,"Biostatistical Consulting",False,"Biostatistical Consulting Inc"+"]US")
mapper(usa,"Ascension",False,"Ascension Health Inc"+"]US")
mapper(usa,"California Emerging Infections ",False,"California Emerging Infections Program"+"]US")
mapper(usa,"Mid-America Transplant",False,"Mid-America Transplant"+"]US")
mapper(usa,"Eloxx",False,'Eloxx Pharma Inc'+"]US")
mapper(usa,"Veloxis",False,"Veloxis Pharma Inc"+"]DK")
mapper(usa,"Patient Advocate",False,"Patient Advocate"+"]US")
mapper(usa,"UNMC",False,"University of Nebraska System"+"]US")
mapper(usa,"eGenesis",False,"eGenesis Inc"+"]US")
mapper(usa,"Arkana Lab",False,"Arkana Labs Inc"+"]US")
mapper(usa,"Miller School",False,"University of Miami"+"]US")
mapper(usa,"Philadelphia Department of Public Health",False,"City of Philadelphia"+"]US")
mapper(usa,"Foodsmart",False,"Foodsmart Inc"+"]US")
mapper(usa,"Central Health",False,"Central Health"+"]US")
mapper(usa,"Ochsner Health",False,"Ochsner Health System"+"]US")
mapper(usa,"Novartis",False,"Novartis Inc"+"]CH")
mapper(usa,"Georgia Department of Public Health",False,"Georgia Department of Public Health"+"]US")
mapper(usa,"UTHSC",False,"University of Tennesse System"+"]US")
mapper(usa,"VCU Medical",False,"Virginia Commonwealth University"+"]US")
mapper(usa,"Centers for Dialysis",False,"Centers for Dialysis Care"+"]US")
mapper(usa,"Alnylam Pharma",False,"Alnylam Pharma Inc"+"]US")
mapper(usa,"South Texas renal care",False,"South Texas Renal Care"+"]US")
mapper(usa,"Michigan Department of Health",False,"Michigan Department of Health and Human Services"+"]US")
mapper(usa,"Brown and Toland",False,"Brown and Toland"+"]US")
mapper(usa,"Valley Children's",False,"Stanford University"+"]US")
mapper(usa,"Oregon Health Authority",False,"Oregon Health Authority"+"]US")
mapper(usa,"Centers for Disease Control",False,"CDC"+"]US")
mapper(usa,"Baystate Medical",False,"Baystate Health"+"]US")
mapper(usa,"Sawtooth Epidemiology",False,"Sawtooth Epidemiology Inc"+"]US")
mapper(usa,"Tonix Pharma",False,"Tonix Inc"+"]US")
mapper(usa,"AZ Delta",False,"AZ Delta "+"]BE")
mapper(usa,"AZ Sint-Jan",False,"AZ Sint-Jan"+"]BE")
mapper(usa,"Capital Health Cancer Center",False,"New York Institute of Technology"+"]US")
mapper(usa,"Advanced clinical trials for children",False,"I ACT"+"]US")
mapper(usa,"Salt Lake County Health",False,"Salt Lake County Health Department"+"]US")
mapper(usa,"La Maestra Community Health Centers",False,"La Maestra Community Health Centers"+"]US")
mapper(usa,"Cormedix",False,"Cormedix Inc"+"]US")
mapper(usa,"Southwest Immuno",False,"Southwest Immunodiagnotistics Inc"+"]US")
mapper(usa,"Minnesota Department of Health",False,"Minnesota Department of Health"+"]US")
mapper(usa,"Renal Physicians Association",False,"Renal Physicians Association"+"]US")
mapper(usa,"Piedmont Transplant",False,"Piedmont Transplant"+"]US")
mapper(usa,"Fundación Clínica San Francisco",False,"Fundación Clínica San Francisco"+"]US")
mapper(usa,"HealthPartners",False,"HealthPartners Inc"+"]US")
mapper(usa,"National Association of Nephrology Technicians",False,"National Association of Nephrology Technicians"+"]US")
mapper(usa,"Lincoln Nephr",False,"Lincoln Nephrology"+"]US")

# %%
world_unis = list(pd.read_csv('world-universities.csv')['Uni'])

# %%
abrev_uni = pd.read_csv('world-universities.csv')[['Abrev','Uni']]

# %%
abrev_uni['TEST'] = abrev_uni['Uni'] + ']' + abrev_uni['Abrev']

# %%
zip(abrev_uni['Uni'],abrev_uni['TEST'])

# %%
def mapper(df, search, case, parent):
    df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
canada['PARENT'] = ""
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(canada, uni, True, test)
mapper(canada, "University Health Network", False, "University of Toronto"+"]CA")
mapper(canada, "University of Montreal", True, "Université de Montréal"+"]CA")
mapper(canada, "Hospital for Sick Children", False, "University of Toronto"+"]CA")
mapper(canada, "Toronto General Hospital", False, "University of Toronto"+"]CA")
mapper(canada, "Ottawa Hospital", False, "University of Ottawa"+"]CA")
mapper(canada, "Lawson Health Research Institute", False, "Western University"+"]CA")
mapper(canada, "Institute for Clinical Evaluative Sciences", False, "Institute for Clinical Evaluative Sciences"+"]CA")
mapper(canada, "ICES", False, "Institute for Clinical Evaluative Sciences"+"]CA")
mapper(canada, "St?.? Michael?'?s", False, "University of Toronto"+"]CA")
mapper(canada, "Alberta Transplant", False, "University of Alberta"+"]CA")
mapper(canada, "Sinai Health", False, "Sinai Health"+"]CA")
mapper(canada, "CHU de Québec", False, "Laval University"+"]CA")
mapper(canada, "Laval University", False, "Laval University"+"]CA")
mapper(canada, "Sunnybrook Research", False, "University of Toronto"+"]CA")
mapper(canada, "Sunnybrook Health", False, "University of Toronto"+"]CA")
mapper(canada, "Providence Health", False, "University of Toronto"+"]CA")
mapper(canada, "Providence Health", False, "University of Toronto"+"]CA")
mapper(canada, "Shared Health", False, "Shared Health"+"]CA")
mapper(canada, "Memorial University", False, "Memorial University"+"]CA")
mapper(canada, "Scarborough Health", False, "University of Toronto"+"]CA")
mapper(canada, "Mazankowski Alberta Heart Institute", False, "University of Alberta"+"]CA")
mapper(canada, "National Research Council", False, "National Research Council CA"+"]CA")
mapper(canada, "Mackenzie Health", False, "Mackenzie Health"+"]CA")
mapper(canada, "Population Health Research Institute", False, "McMaster University"+"]CA")
mapper(canada, "Transcriptome", False, "Transcriptome Inc"+"]CA")
mapper(canada, "Canadian Donation and Transplantation Research", False, "Canadian Donation and Transplantation Research"+"]CA")
mapper(canada, "Pulse Infoframe", False, "Pulse Infoframe Inc"+"]CA")
mapper(canada, "Community?-?Based Research centre", False, "Community Based Research Center"+"]CA")
mapper(canada, "Seven Oaks Hospital", False, "Winnipeg Regional Health Authority"+"]CA")
mapper(canada, "BC Renal", False, "BC Renal"+"]CA")
mapper(canada, "British Columbia Provincial Renal Agency", False, "BC Renal"+"]CA")
mapper(canada, "E.M. Uleryk Consulting", False, "E.M. Uleryk Consulting"+"]CA")
mapper(canada, "Grand River Hospital", False, "McMaster University"+"]CA")
mapper(canada, "Grand River Hospital", False, "McMaster University"+"]CA")
mapper(canada, "Transplant Québec", False, "Transplant Quebec"+"]CA")
mapper(canada, "Trillium Health", False, "University of Toronto"+"]CA")
mapper(canada, "Aurinia Pharmaceuticals", False, "Aurinia Pharmaceuticals Inc"+"]CA")
mapper(canada, "Ontario Renal", False, "Ontario Health"+"]CA")
mapper(canada, "London Health Sciences", False, "Western University"+"]CA")
mapper(canada, "William Osler Health", False, "William Osler Health"+"]CA")
mapper(canada, "Vancouver Coastal Health Research Institute", False, "University of British Columbia"+"]CA")
mapper(canada,"Ajmera Transplant",False,"University of Toronto"+"]CA")
mapper(canada,"Humber River Hospital",False,"University of Toronto"+"]CA")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
china['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(china, uni, True, test)
mapper(china, "Second Military Medical", False, "Naval Medical University"+"]CN")
mapper(china, "Naval Medical University", False, "Naval Medical University"+"]CN")
mapper(china, "Capital Medical University", False, "Capital Medical University"+"]CN")
mapper(china, "Zhengzhou university", False, "Zhengzhou University"+"]CN")
mapper(china, "Sun Yat-Sen university", False, "Sun Yat-Sen University"+"]CN")
mapper(china, "Southern Medical University",False, "Southern Medical University"+"]CN")
mapper(china, "Peking Union Medical College", False, "Peking Union Medical College"+"]CN")
mapper(china, "Shanghai Jiao Tong University", False, "Shanghai Jiao Tong University"+"]CN")
mapper(china, 'Guangzhou medical university', False, "Guangzhou Medical University"+"]CN")
mapper(china, 'Guangdong medical university', False, "Guangdong Medical University"+"]CN")
mapper(china, "Guangdong Academy of Medical Sciences", False, "GDAS"+"]CN")
mapper(china, "Guangdong provincial people's Hospital", False , "GDAS"+"]CN")
mapper(china, "China Medical University", False , "China Medical University"+"]CN")
mapper(china, 'Shandong first medical university', False, "Shandong University"+"]CN")
mapper(china, 'Beijing University of Chinese Medicine', False, "Beijing University of Chinese Medicine"+"]CN")
mapper(china, "Army Medical University", False, "Army Medical University"+"]CN")
mapper(china, "Zhejiang Chinese Medical University", False, "Zhejiang Chinese Medical University"+"]CN")
mapper(china, "Zhejiang Medical University", False, "Zhejiang University"+"]CN")
mapper(china, "Tung Wah Hospital", False, "University of Hong Kong"+"]HK")
mapper(china, "Chinese Academy of Medical Sciences", False, "Peking Union Medical College"+"]CN")
mapper(china, "Tuen Mun Hospital", False, "Hospital Authority"+"]CN")
mapper(china, "Hospital Authority", False, "Hospital Authority"+"]CN")
mapper(china, "Hong Kong children's", False, "University of Hong Kong"+"]HK")
mapper(china, "huizhou municipal central hospital",False,'Huizhou Municipal Central Hospital'+"]CN")
mapper(china, "Kailuan General", False, "Kailuan General Hospital"+"]CN")
mapper(china, "Hunan Clinical Research Center of Ophthalmic Disease", False, "Hunan Clinical Research Center of Ophthalmic Disease"+"]CN")
mapper(china,"Jiangxi Provincial Children's", False, "Jiangxi Provincial Children's Hospital"+"]CN")
mapper(china, "beijing municipal key laboratory of clinical epidemiology", False, "Capital Medical University"+"]CN")
mapper(china, "first people's hospital of foshan", False, "Pyrexar Medical"+"]CN")
mapper(china, "Huazhong University of Science & Technology", False, "Huazhong University of Science and Technology"+"]CN")
mapper(china, "Shenzhen Maternity & Child Healthcare Hospital", False,'Shenzhen Maternity and Child Healthcare Hospital'+"]CN")
mapper(china, 'Hong Kong Science and Technology Park',False,'Hong Kong Science and Technology Park'+"]HK")
mapper(china, 'Queen Mary Hospital',False,'University of Hong Kong'+"]HK")
mapper(china, "Key Laboratory of Chronic Kidney Disease Prevention and Treatment", False, "Peking University"+"]CN")
mapper(china, "Mengniu", False, "Mengniu Ltd"+"]CN")
mapper(china, "BGI", False, "BGI Ltd"+"]CN")
mapper(china, "Beijing institute of biotech", False, "Beijing North Institute of Biotechnology Ltd"+"]CN")
mapper(china, "Maoming People's Hospital", False, "Maoming People's Hospital"+"]CN")
mapper(china, "Liver Disease Prevention and Treatment Research Foundation", False, "Liver Disease Prevention and Treatment Research Foundation"+"]CN")
mapper(china, "DHC", False, "DHC Ltd"+"]CN")
mapper(china, "Renji Hospital", False, "Shanghai Jiao Tong University"+"]CN")
mapper(china, "Three Gorges University", False, "Three Gorges University"+"]CN")
mapper(china, "GlaxoSmithKline", False, "GlaxoSmithKline Inc"+"]GB")
mapper(china, 'KingMed',False,'KingMed Diagnostic Ltd'+"]CN")
mapper(china, 'Beijing Haidian', False, "Peking University"+"]CN")
mapper(china, "Zhejiang provincial people's hospital",False,"Hangzhou Medical College"+"]CN")
mapper(china, "Ningxia Medical University",False,"Ningxia Medical University"+"]CN")
mapper(china, "Sichuan Provincial People's Hospital",False,"University of Electronic Science and Technology of China"+"]CN")
mapper(china, "Shenzhen Zaozhidao Technology",False, "Zaozhidao Technology Ltd"+"]CN")
mapper(china,"Prince of Wales Hospital", False, "Hospital Authority"+"]CN")
mapper(china,"The People's Hospital of Guangxi Zhuang",False, "GXAS"+"]CN")
mapper(china,"Biomedical Imaging Center",False,"Biomedical Imaging Center"+"]CN")
mapper(china,"Beijing Friendship Hospital",False,"Capital Medical University"+"]CN")
mapper(china,"Chinese PLA General",False,"PLA"+"]CN")
mapper(china,"Guangzhou National Lab",False, "Guangzhou National Laboratory"+"]CN")
mapper(china,"Fourth Military Medical",False, "Fourth Military Medical University"+"]CN")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
canada
# Out:
#                                              Unnamed: 0  \
# 10    Division of Pathology, Hôpital Maisonneuve-Ros...
# 21    Ajmera Transplant Centre, University Health Ne...
# 28    Multi-Organ Transplant Program, Ajmera Transpl...
# 43    Ajmera Transplant Centre, University Health Ne...
# 44    Division of Nephrology, Department of Medicine...
# ...                                                 ...
# 4273  Men's Health Clinic Manitoba, University of Ma...
# 4275  Department of Medicine, Université de Montréal...
# 4288  Department of Medicine, Mount Sinai Hospital, ...
# 4319  Community-Based Research Centre, Vancouver, Br...
# 4320  Department of Health Research Methodology, Evi...
#
#                                   PARENT
# 10             Université de Montréal]CA
# 21              University of Toronto]CA
# 28              University of Toronto]CA
# 43              University of Toronto]CA
# 44                McMaster University]CA
# ...

# %%
uk['PARENT'] = ""
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(uk, uni, True, test)
mapper(uk,"Cambridge University", True, "University of Cambridge"+"]GB")
mapper(uk,"Queen Elizabeth University", True, "Queen Elizabeth University"+"]GB")
mapper(uk, "Imperial College", False, "Imperial College London"+"]GB")
mapper(uk, "Ninewells Hospital", False, "University of Dundee"+"]GB")
mapper(uk, "Manchester University", False, "University of Manchester"+"]GB")
mapper(uk, "Guy's St thomas Hospital", False, "King's College"+"]GB")
mapper(uk, "Guy's & St thomas' Hospital", False, "King's College"+"]GB")
mapper(uk, "Guy's and St thomas'", False, "King's College"+"]GB")
mapper(uk, "University Hospital Birmingham", False, "University of Birmingham"+"]GB")
mapper(uk, "University Hospitals Birmingham", False, "University of Birmingham"+"]GB")
mapper(uk, "Queen Elizabeth Hospital", False, "University of Birmingham"+"]GB")
mapper(uk, "Birmingham Children's", False, "University of Birmingham"+"]GB")
mapper(uk, "Birmingham Women's", False, "University of Birmingham"+"]GB")
mapper(uk, "Institute for Health Research Applied Research ", False, "University of Birmingham"+"]GB")
mapper(uk, "Newcastle", False, "Newcastle University"+"]GB")
mapper(uk, "GlaxoSmithKline", False, "GlaxoSmithKline Inc"+"]GB")
mapper(uk, "NHS blood and transplant", False, "NHS"+"]GB")
mapper(uk, "National Health Service blood and transplant", False, "NHS"+"]GB")
mapper(uk, "Oxford University", False, "University of Oxford"+"]GB")
mapper(uk, "University Hospital Southampton", False, "University of Southhampton"+"]GB")
mapper(uk, "University of Southampton", False, "University of Southhampton"+"]GB")
mapper(uk, "Salford Royal Hospital", False, "University of Salford"+"]GB")
mapper(uk, "Leeds", False, "University of Leeds"+"]GB")
mapper(uk, "Royal Free Hospital", False, "University College London"+"]GB")
mapper(uk, "Evelina London", False, "King's College"+"]GB")
mapper(uk, "National Institute for Health and Care Research", False, "NIHR"+"]GB")

mapper(uk, "Royal London Hospital", False, "Queen Mary University"+"]GB")
mapper(uk, "Royal Derby Hospital", False, "University of Nottingham"+"]GB")
mapper(uk, "Nuffield Depart", False, "Nuffield Department of Public Health"+"]GB")
mapper(uk, "Royal Free London", False, "University College London"+"]GB")
mapper(uk, "PAREXEL", False, "PAREXEL Inc"+"]US")
mapper(uk, "Royal London Hospital", False, "Queen Mary University"+"]GB")
mapper(uk, "Sheffield Teaching", False, "University of Sheffield"+"]GB")
mapper(uk, "Northern General", False, "University of Sheffield"+"]GB")
mapper(uk, "Bristol Royal", False, "University of Bristol"+"]GB")
mapper(uk, "Derby and Burton", False, "University of Nottingham"+"]GB")
mapper(uk, "Nottingham Children's ", False, "University of Nottingham"+"]GB")
mapper(uk, "KJC statistics", False, "KJC Statistics"+"]GB")
mapper(uk, "Royal Manchester", False, "University of Manchester"+"]GB")
mapper(uk, "UK Kidney Association", False, "UK Kidney Association"+"]GB")
mapper(uk, "Royal Preston Hospital", False, "University of Central Lancashire"+"]GB")
mapper(uk, "Addenbrooke's Hospital", False, "University of Cambridge"+"]GB")
mapper(uk, "Patient", True, "EMIS Health"+"]GB")
mapper(uk, "Randox", False, "Randox Ltd"+"]GB")
mapper(uk, "Charles River Associates", False, "CRA Inc"+"]US")
mapper(uk, "Papworth Hospital", False, "University of Cambridge"+"]GB")
mapper(uk, "London School of Hygiene and Tropical Medicine", False, "University of London"+"]GB")
mapper(uk, "UK Health Security Agency", False, "DHSC"+"]GB")

mapper(uk, "NIHR", False, "NIHR"+"]GB")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
korea['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(korea, uni, True, test)
mapper(korea,"Sungkyunkwan",  False, "Sungkyunkwan University"+"]KR")
mapper(korea,"Seoul National",  False, "Seoul National University"+"]KR")
mapper(korea,"Boramae Medical",  False, "Seoul National University"+"]KR")
mapper(korea,"University of Ulsan",  False, "University of Ulsan"+"]KR")
mapper(korea,"Asan Medical Center",  False, "University of Ulsan"+"]KR")
mapper(korea,"National Health Insurance Service",  False, "National Health Insurance Service"+"]KR")
mapper(korea,"Institute for Basic Science",  False, "Institute for Basic Science"+"]KR")
mapper(korea,"Korea Advanced Institute of Science and Technology",False,"Korea Advanced Institute of Science and Technology"+"]KR")
mapper(korea,"Jeonbuk National University",False,"Jeonbuk National University"+"]KR")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
australia['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(australia, uni, True, test)

mapper(australia,"Sunshine Coast University", False, "University of the Sunshine Coast"+"]AU")
mapper(australia,"Monash Health", False, "Monash University"+"]AU")
mapper(australia, "UNSW", False, "University of New South Wales"+"]AU")
mapper(australia, "St?. Vincent's", False, "University of Melbourne"+"]AU")
mapper(australia, "St?. George", False, "University of New South Wales"+"]AU")
mapper(australia, "University New South Wales", False, "University of New South Wales"+"]AU")
mapper(australia, "Sydney University", False, "University of Sydney"+"]AU")
mapper(australia, "Sydney Medical School", False, "University of Sydney"+"]AU")
mapper(australia, "Royal Prince Alfred Hospital", False, "University of Sydney"+"]AU")
mapper(australia, "Wollongong Hospital", False, "University of Woolloongabba"+"]AU")
mapper(australia, "Princess Alexandra", False, "University of Queensland"+"]AU")
mapper(australia, "Translational Research Institute", False, "University of Queensland"+"]AU")
mapper(australia, "Royal Children's Hospital", False, "University of Melbourne"+"]AU")
mapper(australia, "Adelaide University", False, "University of Adelaide"+"]AU")
mapper(australia, "University of Adelaide", False, "University of Adelaide"+"]AU")
mapper(australia, "Australia and New Zealand Dialysis and Transplant Registry", False, "Australia and New Zealand Dialysis and Transplant Registry"+"]AU")
mapper(australia, "Baker Heart and Diabetes Institute", False, "Baker Heart and Diabetes Institute"+"]AU")
mapper(australia, "Sir Charles", False, "University of Western Australia"+"]AU")
mapper(australia, "Queensland Children's", False, "University of Queensland"+"]AU")
mapper(australia, "Victor Chang Cardiac", False, "University of New South Wales"+"]AU")
mapper(australia, "Townsville University", False, "Townsville University"+"]AU")
mapper(australia, "Flinders University", False, "Flinders University"+"]AU")
mapper(australia, "Concord Repatriation General Hospital", False, "University of Sydney"+"]AU")
mapper(australia, "Children's Hospital at Westmead", False, "University of Sydney"+"]AU")
mapper(australia, "Centre for Kidney Research", False, "University of Sydney"+"]AU")
mapper(australia, "Prince of Wales", False, "University of New South Wales"+"]AU")
mapper(australia, "Westmead Hospital", False, "University of Sydney"+"]AU")
mapper(australia, "Royal Brisbane and Women's", False, "University of Queensland"+"]AU")
mapper(australia, "George institute", False, "University of New South Wales"+"]AU")
mapper(australia, "Peter Maccallum", False, "University of Melbourne"+"]AU")
mapper(australia, "Royal Melbourne Hospital", False, "University of Melbourne"+"]AU")
mapper(australia, "Austin Health", False, "University of Melbourne"+"]AU")
mapper(australia, "Sydney Children's", False, "University of New South Wales"+"]AU")
mapper(australia, "Murdoch Children's", False, "University of Melbourne"+"]AU")
mapper(australia, "Royal Adelaide Hospital", False, "University of Adelaide"+"]AU")
mapper(australia, "Perth Children's", False, "CAHS Western Australia"+"]AU")
mapper(australia, "Alfred Hospital", False, "Monash University"+"]AU")
mapper(australia, "Lyell McEwin", False, "Monash University"+"]AU")
mapper(australia, "QIMR", False, "QIMR"+"]AU")
mapper(australia, "School of Public Health, Herston", False, "University of Queensland"+"]AU")
mapper(australia, "Pathology Queensland", False, "University of Queensland"+"]AU")
mapper(australia, "Canberra Health Services", False, "Canberra Health Services"+"]AU")
mapper(australia, "Royal North Shore Hospital", False, "University of Sydney"+"]AU")
mapper(australia, "James Cook University", False, "James Cook University"+"]AU")
mapper(australia, "Faculty of Medicine, Herston", False, "University of Queensland"+"]AU")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
brussels['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(brussels, uni, True, test)
mapper(brussels, "KU Leuven", False, "KU Leuven"+"]BE")
mapper(brussels, "Ghent University", False, "Ghent University"+"]BE")
mapper(brussels, "UZ Leuven", False, "KU Leuven"+"]BE")
mapper(brussels, "University Hospitals Leuven", False, "KU Leuven"+"]BE")
mapper(brussels, "University of Antwerp", False, "University of Antwerp"+"]BE")
mapper(brussels, "University Hospital Antwerp", False, "University of Antwerp"+"]BE")
mapper(brussels, "Cliniques universitaires Saint-Luc", False, "University of Louvain"+"]BE")
mapper(brussels, "UCL", False, "University of Louvain"+"]BE")
mapper(brussels, "Université catholique", False, "University of Louvain"+"]BE")
mapper(brussels, "University Hospital of Liège", False, "University of Liege"+"]BE")
mapper(brussels, "Imelda Hospital", False, "Imelda Hospital"+"]BE")
mapper(brussels, "Institute of Tropical Medicine", False, "Institute of Tropical Medicine Antwerp"+"]BE")
mapper(brussels, "University of Liège", False, "University of Liege" +"]BE")
mapper(brussels, "Marie Curie Hospital", False, "Marie Curie Hospital"+"]BE")
mapper(brussels, "EKHA", False, "EKHA"+"]BE")
mapper(brussels, "Sciensano", False, "Sciensano"+"]BE")
mapper(brussels, "Institut de Pathologie et de Génétique", False ,"Institute of Pathology and Genetics"+"]BE")
mapper(brussels, "Grand Hôpital de Charleroi", False, "Grand Hôpital de Charleroi"+"]BE")
mapper(brussels, "Université Libre de Bruxelles", False, "Université Libre de Bruxelles" + "]BE")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
nether['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(nether, uni, True, test)
mapper(nether, 'Radboud University', False, 'Radboud University'+"]NL")
mapper(nether, 'Erasmus University', False, 'Erasmus University'+"]NL")
mapper(nether, "University Medical Center Rotterdam", False, "Erasmus University"+"]NL")
mapper(nether, "Erasmus Medical Center", False, "Erasmus University"+"]NL")
mapper(nether, "Erasmus M", False, "Erasmus University"+"]NL")
mapper(nether, "University Medical Cent?r??e? Groningen", False, "University of Groningen"+"]NL")
mapper(nether, "University Medical Center Groningen", False, "University of Groningen"+"]NL")
mapper(nether, "Groningen University", False, "University of Groningen"+"]NL")
mapper(nether, "Maastricht University", False, "Maastricht University"+"]NL")
mapper(nether, "Amsterdam University", False, "University of Amsterdam"+"]NL")
mapper(nether, "Amsterdam Gastroenterology, Endocrinology and Metabolism", False, "University of Amsterdam"+"]NL")
mapper(nether, "Academic Medical Center, Amsterdam", False, "University of Amsterdam"+"]NL")
mapper(nether, "Jeroen Bosch Hospital", False, "Jeroen Bosch Hospital"+"]NL")
mapper(nether, "Haga Hospital", False, "Haga Hospital"+"]NL")
mapper(nether, "Martini Hospital", False, "Santeon Association"+"]NL")
mapper(nether, "St. Antonius", False, "Santeon Association"+"]NL")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
italy['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(italy, uni, True, test)
mapper(italy, "University of Genova", False, 'University of Genova'+"]IT")
mapper(italy, "Universitaria di Bologna", False, 'University of Bologna'+"]IT")
mapper(italy, "University of Rome", False, 'University of Rome'+"]IT")
mapper(italy, "University of Campania", False, 'University of Campania'+"]IT")
mapper(italy, "Careggi University", False, 'Careggi University'+"]IT")
mapper(italy, "IRCCS", False, 'IRCCS'+"]IT")
mapper(italy, "ASST", False, 'ASST'+"]IT")
mapper(italy, "University Hospital of Padova", False, 'University of Padova'+"]IT")
mapper(italy, "University of Padova", False, 'University of Padova'+"]IT")
mapper(italy, "National Institute of Health", False, 'ISS'+"]IT")
mapper(italy, "University of Pisa", False, 'University of Pisa'+"]IT")
mapper(italy, "University Hospital of Pisa", False, 'University of Pisa'+"]IT")
mapper(italy, "Universitaria Pisana", False, 'University of Pisa'+"]IT")
mapper(italy, "National Research Council", False, 'CNR'+"]IT")
mapper(italy, "Azienda Ospedaliera Brotzu", False, 'University of Cagliari'+"]IT")
mapper(italy, "Universitaria di Parma",False, "University of Parma"+"]IT")
mapper(italy, "IRES",False, "IRES"+"]IT")
mapper(italy, "Università degli Studi di Milano", False, "University of Milan"+"]IT")
mapper(italy, "Federico II University Hospital", False, "University of Naples Federico II"+"]IT")
mapper(italy, "Università degli Studi della Campania", False, "University of Campania Luigi Vanvitelli"+"]IT")
mapper(italy, "University of Piemonte Orientale", False, "University of Piemonte Orientale"+"]IT")
mapper(italy, "Università degli Studi di Napoli Federico II", False, "University of Naples Federico II"+"]IT")
mapper(italy, "Giovanni XXIII", False, "University of Milan"+"]IT")
mapper(italy, "University Hospital of Padua", False, "University of Padua"+"]IT")
mapper(italy, "University and Civil Hospital", False, "University and Civil Hospital"+"]IT")
mapper(italy, "Università di Siena", False, "University of Siena"+"]IT")
mapper(italy, "Policlinico San Martino", False, "IRCCS"+"]IT")
mapper(italy, "Cisanello Hospital", False, "University of Pisa"+"]IT")
mapper(italy, "Santobono-Pausilipon", False, "Santobono-Pausilipon"+"]IT")
mapper(italy, "Cardarelli Hospital", False, "University of Molise"+"]IT")
mapper(italy, "Niguarda Ca' Granda Hospital", False, "University of Milan"+"]IT")
mapper(italy, "AUSL Toscana", False, "AUSL Tuscany"+"]IT")
mapper(italy, "Cannizzaro Hospital", False, "Cannizzaro Hospital"+"]IT")
mapper(italy, "Santo Stefano Hospital", False, "AUSL Tuscany"+"]IT")
mapper(italy, "Sant'Orsola-Malpighi", False, "University of Bologna"+"]IT")
mapper(italy, "G. Martino", False, "University of Messina" +"]IT")
mapper(italy, "Umberto I", False, "University of Rome Sapienza" +"]IT")
mapper(italy, "Grande Ospedale Metropolitano, Reggio Calabria", False, "Great Metropolitan Hospital of 'Bianchi-Melacrino-Morelli'" +"]IT")
mapper(italy, "Villaserena", False, "Villa Serena"+"]IT")
mapper(italy, "Bambino Gesù Children's Hospital", False, "Bambino Gesù Children's Hospital"+"]IT")
mapper(italy, "San Giovanni di Dio e Ruggi d'Aragona", False, "University of Salerno"+"]IT")
mapper(italy, "Santa Maria Annunziata", False, "AUSL Tuscany"+"]IT")
mapper(italy, "SS Annunziata", False, "SS Annuziata"+"]IT")
mapper(italy, "Fondazione Ricerca Molinette", False, "Fondazione Ricerca Molinette"+"]IT")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
mex['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(mex, uni, True, test)
mapper(mex, "Salvador Zubirán", False, "Instituto Nacional de Ciencias Médicas y Nutrición Salvador Zubirán"+"]MX")
mapper(mex, "Salvador Zubiran", False, "Instituto Nacional de Ciencias Médicas y Nutrición Salvador Zubirán"+"]MX")
mapper(mex, "Instituto Nacional de Cardiología Ignacio Chávez", False, "Instituto Nacional de Cardiología Ignacio Chávez"+"]MX")
mapper(mex, "CHRISTUS", False, "CHRISTUS"+"]MX")
mapper(mex, "Charles River Associates", False, "CRA Inc"+"]GB")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
nz['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(nz, uni, True, test)
mapper(nz, "Auckland University", False, "University of Auckland"+"]NZ")
mapper(nz, "Auckland", False, "University of Auckland"+"]NZ")
mapper(nz, "Eastern Institute", False, "Eastern Institute of Technology"+"]NZ")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
pol['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(pol, uni, True, test)
mapper(pol, "Medical University of Lublin", False, "Medical University of Lublin"+"]PL")
mapper(pol, "Medical University of Silesia", False, "Medical University of Silesia"+"]PL")
mapper(pol, "Jagiellonian University", False, "Jagiellonian University"+"]PL")
mapper(pol, "Children's Memorial Health Institute", False, "Children's Memorial Health Institute"+"]PL")
mapper(pol, "University of Zielona Góra", False, "University of Zielona Góra"+"]PL")
mapper(pol, "University of Medical Sciences", False, "Adam Mickiewicz University"+"]PL")
mapper(pol, "Wrocław Medical University,", False, "Wroclaw Medical University"+"]PL")
mapper(pol, "Wroclaw Medical University,", False, "Wroclaw Medical University"+"]PL")
mapper(pol, "Medical University of Gdańsk", False, "Medical University of Gdansk"+"]PL")
mapper(pol, "Pomeranian Medical University", False, "Pomeranian Medical University"+"]PL")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
austria['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(austria, uni, True, test)
mapper(austria, "Medical University of Vienna", False,"Medical University of Vienna"+"]AT")
mapper(austria, "Medical University of Innsbruck", False,"Medical University of Innsbruck"+"]AT")
mapper(austria, "Medical University Innsbruck", False,"Medical University of Innsbruck"+"]AT")
mapper(austria, "Johannes Kepler", False,"Johannes Kepler University"+"]AT")
mapper(austria, "Boehringer Ingelheim", False, "Boehringer Ingelheim KG"+"]DE")
mapper(austria, "Hanusch Hospital", False, "Hanusch Hospital"+"]AT")
mapper(austria,"Medizinische Universität Wien",False,"Medical University of Vienna"+"]AT")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
argen['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(austria, uni, True, test)
mapper(argen, "National University of La Plata", False,"National University of La Plata"+"]AR")
mapper(argen, "Hospital Británico de Buenos Aires", False, "University of Buenos Aires"+"]AR")
mapper(argen, "ITAC", False, "ITAC"+"]AR")
mapper(argen, "Hospital Italiano de Buenos Aires", False, "Instituto Universitario Hospital Italiano de Buenos Aires"+"]AR")
mapper(argen, "Centro de Diagnostico Patologico", False, "Centro de Diagnostico Patologico"+"]AR")
mapper(argen, "Hospital de Niños", False, "Hospital de Niños"+"]AR")
mapper(argen, "Hospital Pediátrico Humberto J Notti", False, "Government of Mendoza"+"]AR")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
mid['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(mid, uni, True, test)
mapper(mid, 'Gazi University', False, 'Gazi University'+"]TR")
mapper(mid, 'King Khalid University', False, 'King Khalid University'+"]SA")
mapper(mid, 'Koç University Hospital', False, 'Koc University'+"]TR")
mapper(mid, 'Cornell', False, 'Cornell University'+"]US")
mapper(mid, 'Tehran University', False, 'Tehran University'+"]IR")
mapper(mid, 'Mohammed Bin Rashid University', False, 'Mohammed Bin Rashid University'+"]AE")
mapper(mid, 'Cleveland Clinic', False, 'Case Western Reserve University'+"]US")
mapper(mid, "King Faisal Specialist", False, "Alfaisal University"+"]SA")
mapper(mid, "Uludağ University", False, "Uludağ University"+"]TR")
mapper(mid, "Acibadem", False, "Acibadem"+"]TR")
mapper(mid, "Al Jalila Children's", False, "Al Jalila Children's"+"]AE")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
sing['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(sing, uni, True, test)
mapper(sing, "National University of Singapore", False, "National University of Singapore"+"]SG")
mapper(sing, "NUS", False, "National University of Singapore"+"]SG")
mapper(sing, "Singapore General Hospital", False, "National University of Singapore"+"]SG")
mapper(sing, "Agency for Science, Technology and Research", False, "Agency for Science, Technology and Research"+"]SG")
mapper(sing, "Mount Elizabeth", False, "Parkway Health Ltd"+"]SG")
mapper(sing, "Institute of Mental Health", False, "National Healthcare Group"+"]SG")
mapper(sing, "Singapore Eye Research Institute", False, "National University of Singapore"+"]SG")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
czech['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(czech, uni, True, test)
mapper(czech, "Charles University", False, "Charles University"+"]CZ")
mapper(czech, "Institute for Clinical and Experimental Medicine", False, "Institute for Clinical and Experimental Medicine"+"]CZ")
mapper(czech, "Institute of Clinical and Experimental Medicine", False, "Institute for Clinical and Experimental Medicine"+"]CZ")
mapper(czech, "University Hospital Motol", False, "Charles University"+"]CZ")
mapper(czech, "Biopticka", False, "Biopticka"+"]CZ")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
irish['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(irish, uni, True, test)
mapper(irish, "University of Galway", False, "University of Galway"+"]IE")
mapper(irish, "Trinity College Dublin", False, "Trinity College Dublin"+"]IE")
mapper(irish, "Belfast City Hospital", False, "Queen's University Belfast"+"]IE")
mapper(irish, "Children's Hospital Ireland", False, "Children's Health Ireland"+"]IE")
mapper(irish, "Orbsen Therapeutics", False, "Orbsen Therapeutics Ltd"+"]IE")
mapper(irish, "Randox", False, "Randox Ltd"+"]GB")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
brazil['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(brazil, uni, False, test)
mapper(brazil,"Universidade de São Paulo",False, "University of São Paulo"+"]BR")
mapper(brazil,"University of São Paulo",False, "University of São Paulo"+"]BR")
mapper(brazil,"Universidade de Sao Paulo",False, "University of São Paulo"+"]BR")
mapper(brazil,"University Nove de Julho",False, "University Nove de Julho"+"]BR")
mapper(brazil,"Universidade Nove de Julho",False, "University Nove de Julho"+"]BR")
mapper(brazil,"Faculdade Israelita de Ciências da Saúde Albert Einstein",False, "Albert Einstein Israelite Hospital"+"]BR")
mapper(brazil,"Hospital Israelita Albert Einstein",False, "Albert Einstein Israelite Hospital"+"]BR")
mapper(brazil,"Dasa",False, "Dasa Inc"+"]BR")
mapper(brazil, "Beneficência Portuguesa", False, "Beneficência Portuguesa"+"]BR")
mapper(brazil, "Santa Casa de São Paulo", False, "Santa Casa de São Paulo School of Medicine"+"]BR")
mapper(brazil, "UNIMES", False, "University Metropolitana de Santos"+"]BR")
mapper(brazil, "UNICAMP", False, "State University of Campinas"+"]BR")
mapper(brazil, "Hospital Sirio-Libanes", False, "Hospital Sirio-Libanes"+"]BR")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
swiss['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(swiss, uni, False, test)
mapper(swiss, "University Hospital Zürich", False, "University of Zürich"+"]CH")
mapper(swiss, "University Hospital Zurich", False, "University of Zürich"+"]CH")
mapper(swiss, "University of Zurich", False, "University of Zürich"+"]CH")
mapper(swiss, "CSL", False, "CSL"+"]AU")
mapper(swiss, "University Hospital Basel", False, "University of Basel"+"]CH")
mapper(swiss, "University Hospital of Basel", False, "University of Basel"+"]CH")
mapper(swiss, "University Hospital of Zurich", False, "University of Zürich"+"]CH")
mapper(swiss, "Universitets Hospital Zurich", False, "University of Zürich"+"]CH")
mapper(swiss, "University Hospital of Vaud", False, "University of Lausanne"+"]CH")
mapper(swiss, "Lausanne University", False, "University of Lausanne"+"]CH")
mapper(swiss, "Geneva University", False, "University of Geneva"+"]CH")
mapper(swiss, "Centre hospitalier universitaire Vaud", False, "University of Lausanne"+"]CH")
mapper(swiss, "University of Bern", False, "University of Bern"+"]CH")
mapper(swiss, "Felix Platter", False, "Felix Platter"+"]CH")
mapper(swiss,"Novartis", False, "Novartis AG"+"]CH")
mapper(swiss,"Roche Diagnostics", False, "Roche AG"+"]CH")
mapper(swiss, "SOCAR Research", False, "SOCAR Research"+"]CH")
mapper(swiss, "Cantonal Hospital St Gallen", False, "Cantonal Hospital St Gallen"+"]CH")
mapper(swiss, "Calciscon", False, "Calciscon AG"+"]CH")
mapper(swiss, "roche Ltd", False, "Roche AG"+"]CH")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
japan['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(japan, uni, False, test)
mapper(japan, "Tokyo Women's Medical University", False, "Tokyo Women's Medical University"+"]JP")
mapper(japan, "Fukushima Medical University", False, "Fukushima Medical University"+"]JP")
mapper(japan, "Osaka Medical and Pharmaceutical University", False, "Osaka Medical and Pharmaceutical University"+"]JP")
mapper(japan, "National Center for Child Health and Development", False, "National Center for Child Health and Development"+"]JP")
mapper(japan, "Sanwa Kagaku Kenkyusho Co., Ltd", False, "Sanwa Kagaku Kenkyusho Co., Ltd"+"]JP")
mapper(japan, "Kameda Medical Center", False, "Kameda Medical Center"+"]JP")
mapper(japan, "Okinawa Heart and Renal Association", False, "Okinawa Heart and Renal Association"+"]JP")
mapper(japan, "Hamamatsu Rosai Hospital", False, "Japan Organization of Occupational Health and Safety"+"]JP")
mapper(japan, "Rinku General Medical Center", False, "Rinku General Medical Center"+"]JP")
mapper(japan, "Nakayamadera Imai Clinic", False, "Nakayamadera Imai Clinic"+"]JP")
mapper(japan, "Teine Keijinkai Hospital", False, "Teine Keijinkai Hospital"+"]JP")
mapper(japan, "Chikuseikai Munakata Clinic", False, "Chikuseikai Munakata Clinic"+"]JP")
mapper(japan, "Tessyoukai Kameda Family Clinic", False, "Tessyoukai Kameda Family Clinic"+"]JP")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
india['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(india, uni, False, test)
mapper(india, "Rela institute", False, "Dr. Rela Institute"+"]IN")
mapper(india, "Bharath Institute", False, "Bharath University"+"]IN")
mapper(india, "MIT Hospital", False, "MIT Group"+"]IN")
mapper(india, "Institute of Liver and Biliary Sciences", False, "ILBS"+"]IN")
mapper(india, "Global Hospital", False, "Global Hospitals Inc"+"]IN")
mapper(india, "Gleneagles", False, "Global Hospitals Inc"+"]IN")
mapper(india, "H?.?L?.? Trivedi Institute of Transplantation", False, "Gujarat University of Transplantation Sciences"+"]IN")
mapper(india, "Amrita Hospital", False, "Amrita University"+"]IN")
mapper(india, "Max", False, "Max Health Inc"+"]IN")
mapper(india, "Amrita Institute", False, "Amrita University"+"]IN")
mapper(india, "Apollo Hospital", False, "Apollo Hospitals Ltd"+"]IN")
mapper(india, "Medanta", False, "Medanta Ltd"+"]IN")
mapper(india, "Manipal Hospital", False, "Manipal Hospitals Ltd"+"]IN")
mapper(india, "N. R. S.", False, "NRS Medical College"+"]IN")
mapper(india, "St. John's", False, "St John's Medical College"+"]IN")
mapper(india, "Mahatma Gandhi Medical College", False, "Mahatma Gandhi Medical College"+"]IN")
mapper(india, "Bansal Hospital", False, "Bansal Group Ltd"+"]IN")
mapper(india, "Aster", False, "Aster Health Ltd"+"]IN")
mapper(india, "Seth GS", False, "Maharashtra University of Health Sciences"+"]IN")
mapper(india, "RNTIICS", False, "Narayana Health Ltd"+"]IN")
mapper(india, "Zydus", False, "Zydus Hospitals Ltd"+"]IN")
mapper(india, "Institute of Child Health", False, "WBUHS"+"]IN")
mapper(india, "Lal Path Labs", False, "Dr Lal PathLabs Ltd"+"]IN")
mapper(india, "IQRAA", False, "IQRAA"+"]IN")
mapper(india, "Choithram Hospital", False, "Choithram International Ltd"+"]IN")
mapper(india, "Muljibhai Patel Urological Hospital", False, "Muljibhai Patel Urological Hospital"+"]IN")
mapper(india, "Fortis", False, "Fortis Health Ltd"+"]IN")
mapper(india, "Sir Ganga Ram Hospital", False, "Sir Ganga Ram Hospital"+"]IN")
mapper(india, "George Institute", False, "George Institute"+"]IN")
mapper(india, "Yashoda", False, "Yashoda Hospitals Ltd"+"]IN")
mapper(india, "Jaypee", False, "Jaypee Health Ltd"+"]IN")
mapper(india, "Postgraduate Institute of Medical Education and Research", False, "PGIMER"+"]IN")
mapper(india, "Gujarat Kidney Foundation", False, "Gujarat Kidney Foundation"+"]IN")
mapper(india, "Jaslok Hospital", False, "Jaslok Hospital Ltd"+"]IN")
mapper(india, "Epitome Hospital", False, "Epitome Hospitals Ltd"+"]IN")
mapper(india, "KIMS", False, "KIMS Ltd"+"]IN")
mapper(india, "Manipal Academy", False, "MAHE"+"]IN")
mapper(india, "Aditya birla", False, "Aditya Birla Group Ltd"+"]IN")
mapper(india, "Rajagiri", False, "Rajagiri Group Ltd"+"]IN")
mapper(india, "VPS", False, "VPS Health Ltd"+"]IN")
mapper(india, "Kovai", False, "Kovai Ltd"+"]IN")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
denmark['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(denmark, uni, False, test)
mapper(denmark, "University of Copenhagen", False, "Copenhagen University"+"]DK")
mapper(denmark, "steno", False, "Steno"+"]DK")
mapper(denmark, "Herlev and Gentofte", False, "Copenhagen University"+"]DK")
mapper(denmark, "Nordsjællands Hospital", False, "Copenhagen University"+"]DK")
mapper(denmark, "Zealand University Hospital", False, 'Roskilde University'+"]DK")
mapper(denmark, "Rigshospitalet", False, "Copenhagen University"+"]DK")
mapper(denmark, "Capital Region Pharmacy", False, "Copenhagen University"+"]DK")
mapper(denmark, "Novo Nordisk", False, "Novo Nordisk"+"]DK")
mapper(denmark, "Danish National Genome Center", False, "Danish National Genome Center"+"]DK")
mapper(denmark, "Hospitalsenheden Midt", False, "Aarhus University"+"]DK")
mapper(denmark, "Region Hospital Silkeborg", False, "Aarhus University"+"]DK")
mapper(denmark, "Sygehus Lillebælt", False, "Sygehus Lillebælt"+"]DK")
mapper(denmark, "Gødstrup Hospital", False, "Aarhus University"+"]DK")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
taiwan['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(taiwan, uni, False, test)
mapper(taiwan, "Chang Gung", False, "Chang Gung University"+"]TW")
mapper(taiwan, "Taipei Veterans General Hospital", False,"Taipei Veterans General Hospital"+"]TW") 
mapper(taiwan, "National Yang Ming Chiao Tung University", False, "National Yang Ming Chiao Tung University"+"]TW")
mapper(taiwan, "Ministry of Health and Welfare", False, "Ministry of Health and Welfare"+"]TW")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
sweden['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(sweden, uni, False, test)

mapper(sweden,"University of Gothenburg",False,"University of Gothenburg"+"]SE")
mapper(sweden, "Skåne University Hospital", False, "Lund University"+"]SE")
mapper(sweden, "Karolinska Institute", False, "Karolinska Institute"+"]SE")
mapper(sweden, "Karolinska Institutet", False, "Karolinska Institute"+"]SE")
mapper(sweden, "Skane University Hospital", False, "Lund University"+"]SE")
mapper(sweden, "ITB-MED", False, "ITB-MED AB"+"]SE")
mapper(sweden, "Triomed", False, "Triomed AB"+"]SE")
mapper(sweden, "Sahlgrenska University Hospital", False, "University of Gothenburg"+"]SE")
mapper(sweden, "JAMCO Pharma", False, "JAMCO Pharma"+"]SE")
mapper(sweden, "Karolinska University", False, "Karolinska Institute"+"]SE")
mapper(sweden, "AstraZeneca", False, "AstraZeneca Inc"+"]GB")
mapper(sweden, "Office of Medical Services", False, "Office of Medical Services"+"]SE")
mapper(sweden, "Danderyd Hospital", False, "Karolinska Institute"+"]SE")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
the_rest['PARENT'] = ""
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(the_rest, uni, False, test)
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
mapper(the_rest, "CDC", False, "CDC"+"]US")
mapper(the_rest, "Seattle Children", False, "University of Washington"+"]US")
mapper(the_rest, "Helsinki University", False, "University of Helsinki"+"]FI")
mapper(the_rest, "Oslo University", False, "Oslo University"+"]NO")
mapper(the_rest, "St Olav University", False, "Norwegian University of Science and Technology"+"]NO")
mapper(the_rest, "North-West University", False, "North-West University"+"]ZA")
mapper(the_rest, "Akershus University", False, "Oslo University"+"]NO")
mapper(the_rest,"Georges Pompidou",False, "Paris Cité University"+"]FR")
mapper(the_rest,"Pompidou",False, "Paris Cité University"+"]FR")
mapper(the_rest, "St?. Vincent", False, "University of Melbourne"+"]AU")
mapper(the_rest, "St?. George", False, "University of New South Wales"+"]AU")
mapper(the_rest, "Erasmus M", False, "Erasmus University"+"]NL")
mapper(the_rest,"Voronezh State Medical University",False,"Voronezh State Medical University"+"]RU")
mapper(the_rest,"Amsterdam Public Health Research",False,"APH"+"]NL")
mapper(the_rest,"Department of Public Health Sciences, Graduate School of Public Health.",False,"Seoul National University"+"]KR")
mapper(the_rest,"Russian National Research Medical University",False,"Russian National Research Medical University"+"]RU")
mapper(the_rest,"National Medical Research Center for Children's Health",False,"National Medical Research Center for Children's Health"+"]RU")
mapper(the_rest,"Nancy",False,"Henri Poincaré University"+"]FR")
mapper(the_rest,"Sultanah Aminah Hospital",False,"Sultanah Aminah Hospital"+"]MY")
mapper(the_rest,"Hannover Medical School",False,"Hannover Medical School"+"]DE")
mapper(the_rest,"Medical Faculty of Skopje", False, "Medical Faculty of Skopje"+"]MK")
mapper(the_rest,"Fundeni Clinical Institute",False,"UMPCD"+"]RO")
mapper(the_rest,"Besançon",False,"University of Franche-Comté"+"]FR")
mapper(the_rest,"Cleveland Clinic",False,"Case Western Reserve University"+"]US")
mapper(the_rest,"University of Tours",False,"University of Tours"+"]FR")
mapper(the_rest,"Belarus State Medical University",False,"Belarus State Medical University"+"]BY")
mapper(the_rest,"University Hospital of Split",False,"University of Split"+"]HR")
mapper(the_rest,"University of Antioquia",False,"University of Antioquia"+"]CO")
mapper(the_rest,"Primary Children's Hospital",False,"University of Utah"+"]US")
mapper(the_rest,"University of Medicine and Pharmacy",False,"UMF Iași"+"]RO")
mapper(the_rest,"GHESKIO",False,"GHESKIO"+"]HT")
mapper(the_rest,"IIS-Fundación Jimenez Diaz",False,"IIS-Fundación Jimenez Diaz"+"]ES")
mapper(the_rest,"Shupyk National Medical Academy of Postgraduate Education",False,"Shupyk National Medical Academy of Postgraduate Education"+"]UA")
mapper(the_rest,"Rafael Henao Toro",False,"Hospital Infantil Universitario"+"]CO")
mapper(the_rest,"University hospital merkur",False,"University Hospital Merkur"+"]HR")
mapper(the_rest,"Poitier",False,"University of Poitiers"+"]FR")

# %%
france['PARENT'] = ""
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(france, uni, False, test)

mapper(france, "CHU rennes", False, "University of Rennes"+"]FR")
mapper(france, "CHU pont", False, "University of Rennes"+"]FR")
mapper(france, "Robert Debr", False, "Paris Cité University"+"]FR")
mapper(france, "Paris University", False, "Paris Cité University"+"]FR")
mapper(france, "La Piti", False, "Sorbonne University"+"]FR")
mapper(france, "Rennes University", False, "University of Rennes"+"]FR")
mapper(france, "CHU Nantes", False, "Nantes University"+"]FR")
mapper(france, "Nantes University", False, "Nantes University"+"]FR")
mapper(france, "CHU Toulouse", False, "Paul Sabatier University"+"]FR")
mapper(france, "Toulouse University", False, "Paul Sabatier University"+"]FR")
mapper(france, "university hospital, Strasbourg", False, "Strasbourg University"+"]FR")
mapper(france, "university hospital, Nantes", False, "Nantes University"+"]FR")
mapper(france, "Lille university", False, "Lille University"+"]FR")
mapper(france, "CHU Lille", False, "Lille University"+"]FR")
mapper(france,"Université de Paris", False, "Paris Cité University"+"]FR")
mapper(france, "Paris Cité", False, "University of Paris"+"]FR")
mapper(france, "University of Paris", False, "Paris Cité University"+"]FR")
mapper(france, "CHU Bordeaux", False, "University of Bordeaux"+"]FR")
mapper(france, "CHU de Bordeaux", False, "University of Bordeaux"+"]FR")
mapper(france, "Centre Hospitalier Universitaire de Bordeaux", False, "University of Bordeaux"+"]FR")
mapper(france, "Centre Hospitalier Régional Universitaire de Tours", False, "University of Tours"+"]FR")
mapper(france, "CHU Reims", False, "University of Reims"+"]FR")
mapper(france, "Reims Univer", False, "University of Reims"+"]FR")
mapper(france,"Hospices civils de Lyon",False,"Claude Bernard University Lyon 1"+"]FR")
mapper(france, "Foch hospital", False, "University of Paris-Saclay"+"]FR")
mapper(france, "Hopital Foch", False, "University of Paris-Saclay"+"]FR")
mapper(france, "Hôpital Foch", False, "University of Paris-Saclay"+"]FR")
mapper(france, "CHU - Hôtel Dieu",False, "Paris Cité University"+"]FR")
mapper(france,"Georges Pompidou",False, "Paris Cité University"+"]FR")
mapper(france, "Henri-Mondor", False,"Paris-East Créteil University"+"]FR")
mapper(france, "Henri Mondor", False,"Paris-East Créteil University"+"]FR")
mapper(france, "Mère Enfant", False,"Nantes University"+"]FR")
mapper(france, "Mère et de l'Enfant", False,"Nantes University"+"]FR")
mapper(france,"University Hospital, Clermont",False,"University of Auvergne"+"]FR")
mapper(france,"Clermont-Ferrand",False,"University of Auvergne"+"]FR")
mapper(france,"Clermont Auvergne",False,"University of Auvergne"+"]FR")
mapper(france,"Hopital Saint-Louis",False,"Paris Cité University"+"]FR")
mapper(france,"Saint-Louis Hospital",False,"Paris Cité University"+"]FR")
mapper(france,"CHU Saint Louis",False,"Paris Cité University"+"]FR")
mapper(france,"AUB Santé",False,"AUB Santé"+"]FR")
mapper(france,"Hôtel-Dieu de France",False,"Saint Joseph University of Beirut"+"]LB")
mapper(france,"Hôpital Bichat-Claude",False,"Paris Cité University"+"]FR")
mapper(france,"Bichat Claude",False,"Paris Cité University"+"]FR")
mapper(france,"Bichat hospital",False,"Paris Cité University"+"]FR")
mapper(france,"CHRU Clocheville",False,"University of Tours"+"]FR")
mapper(france,"CHU Tours",False,"University of Tours"+"]FR")
mapper(france,'NHC Strasbourg', False,"Strasbourg University"+"]FR")
mapper(france,'MARHEA',False,"Paris Cité University"+"]FR")
mapper(france,"University Hospital of Strasbourg",False,"Strasbourg University"+"]FR")
mapper(france,"Strasbourg University",False,"Strasbourg University"+"]FR")
mapper(france,"CH Epernay", False, "CH Epernay"+"]FR")
mapper(france,'CHU Caen',False,"University of Caen Normandy"+"]FR")
mapper(france,'Caen Normandie',False,"University of Caen Normandy"+"]FR")
mapper(france,'Necker',False, "Paris Cité University"+"]FR")
mapper(france,'Bicetre Hospital',False,"University of Paris-Saclay"+"]FR")
mapper(france,'Kremlin-Bicêtre',False,"University of Paris-Saclay"+"]FR")
mapper(france,'Versailles-Saint-Quentin',False,"University of Paris-Saclay"+"]FR")
mapper(france,'Jules Verne University of Picardie',False,"University of Picardie Jules Verne"+"]FR")
mapper(france,'CHU HEGP',False,"Paris Cité University"+"]FR")
mapper(france,"CHU Purpan",False,"Paul Sabatier University"+"]FR")
mapper(france,"CHU Amiens",False,"University of Picardie Jules Verne"+"]FR")
mapper(france,"Amiens Unive",False,"University of Picardie Jules Verne"+"]FR")
mapper(france,"HCL",False,"Claude Bernard University Lyon 1"+"]FR")
mapper(france,"Lyon",False,"Claude Bernard University Lyon 1"+"]FR")
mapper(france,'Tenon',False,"Sorbonne University"+"]FR")
mapper(france,"Timone",False,"Aix-Marseille University"+"]FR")
mapper(france,'Sorbonne University',False,"Sorbonne University"+"]FR")
mapper(france,'Sorbonne Université',False,"Sorbonne University"+"]FR")
mapper(france,'jeanne de flandre',False,"Lille University"+"]FR")
mapper(france,'Paris-Saclay',False,"University of Paris-Saclay"+"]FR")
mapper(france,'Paris Saclay',False,"University of Paris-Saclay"+"]FR")
mapper(france,"Bichat",False,"Paris Cité University"+"]FR")
mapper(france,"University of Lorraine",False,"Lorraine University"+"]FR")
mapper(france,"Lorraine University",False,"Lorraine University"+"]FR")
mapper(france,"GHM",False,"GHM"+"]FR")
mapper(france,"CHU Limoges",False,"University of Limoges"+"]FR")
mapper(france,"Limoges University",False,"University of Limoges"+"]FR")
mapper(france,"Lille Regional University",False,"Lille University"+"]FR")
mapper(france,"CH Edouart Heriot",False,"Claude Bernard University Lyon 1"+"]FR")
mapper(france,"Montpellier University",False,"Montpellier University"+"]FR")
mapper(france,"University of Montpellier",False,"Montpellier University"+"]FR")
mapper(france,"Arnaud de Villeneuve",False,"Montpellier University"+"]FR")
mapper(france,'AURA', False, "AURA Paris"+"]FR")
mapper(france,"ADPC",False,"ADPC"+"]FR")
mapper(france,"CHU Poitier",False,"University of Poitiers"+"]FR")
mapper(france,"Poitier",False,"University of Poitiers"+"]FR")
mapper(france,"Sanofi",False,"Sanofi Inc"+"]FR")
mapper(france,"CHU Ambroise",False,"University of Paris-Saclay"+"]FR")
mapper(france,"Ambroise",False,"University of Paris-Saclay"+"]FR")
mapper(france,"Paris-Cité",False,"Paris Cité University"+"]FR")
mapper(france,'Rouen',False,"University of Rouen"+"]FR")
mapper(france, "INSERM", False, "INSERM"+"]FR")
mapper(france,"Boulogne-sur",False,"Boulogne-sur-mer Hospital"+"]FR")
mapper(france,"CHU Morvan",False,"University of Western Brittany"+"]FR")
mapper(france,"CHU de Bres",False,"University of Western Brittany"+"]FR")
mapper(france,"CHRU Jean Minjoz",False,"University of Franche-Comté"+"]FR")
mapper(france,"CHU Pellegrin",False,"University of Bordeaux"+"]FR")
mapper(france,"CHU d'Angers",False,"University of Angers"+"]FR")
mapper(france,"CHU Angers",False,"University of Angers"+"]FR")
mapper(france,"Hôpitaux de Marseille", False,"Aix-Marseille University"+"]FR")
mapper(france,"Aix-Marseille", False,"Aix-Marseille University"+"]FR")
mapper(france,"Nice University",False,"Côte d'Azur University"+"]FR")
mapper(france,"CHU de Nice",False,"Côte d'Azur University"+"]FR")
mapper(france,"Clinique Universitaire Pédiatrique",False,"Grenoble Alpes University"+"]FR")
mapper(france,"CHU Besan",False,"University of Franche-Comté"+"]FR")
mapper(france,"Valencien",False,"Polytechnic University of Hauts-de-France"+"]FR")
mapper(france, "University of Liège", False, "University of Liege"+"]FR")
mapper(france, "CH Pontoise",False,"NOVO Hospital"+"]FR")
mapper(france,"Agence de la Biomedecine",False,"ABM"+"]FR")
mapper(france,"Biomedecine Agency",False,"ABM"+"]FR")
mapper(france,"CHU Brugmann",False,"Université libre de Bruxelles"+"]BE")
mapper(france,"Hôpital Trousseau",False,"Sorbonne University"+"]FR")
mapper(france,"Clinique Sainte Anne",False,"GHSV"+"]FR")
mapper(france,"CH Chartres",False,"CH Chartres"+"]FR")
mapper(france,"FHU SUPORT",False,"FHU SUPORT"+"]FR")
mapper(france,'CHU Dijon',False,"University of Burgundy"+"]FR")
mapper(france,'cochin',False,"Paris Cité University"+"]FR")
mapper(france,'CHU Anne de Bretagne',False,"University of Rennes"+"]FR")
mapper(france,'Paris Transplant Group',False,'Paris Transplant Group'+"]FR")
mapper(france,'pital Avicenne',False,'Sorbonne Paris North University'+"]FR")
mapper(france,'Royal Infirmary of Edinburgh',False,"University of Edinburgh"+"]GB")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
spain['PARENT'] = ""
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(spain, uni, False, test)
mapper(spain, "Universitat de Barcelona",False,"University of Barcelona"+"]ES")
mapper(spain,"imas12",False,"Complutense University of Madrid"+"]ES")
mapper(spain,"Complutense",False,"Complutense University of Madrid"+"]ES")
mapper(spain,"Universidad de Córdoba",False,"University of Cordoba"+"]ES")
mapper(spain,"Marqués de Valdecilla",False,"University of Cantabria"+"]ES")
mapper(spain,"Vall d'Hebron",False,"Autonomous University of Barcelona"+"]ES")
mapper(spain,"Organización Nacional de Trasplantes",False,"Organización Nacional de Trasplantes"+"]ES")
mapper(spain,"La Paz University",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"Hospital La Paz",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"Universitario La Paz",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"IIS La Fe",False,"University of Valencia"+"]ES")
mapper(spain,"La Fe Uni",False,"University of Valencia"+"]ES")
mapper(spain,"Hospital La Fe",False,"University of Valencia"+"]ES")
mapper(spain,"University of Valencia",False,"University of Valencia"+"]ES")
mapper(spain,"Hospital Universitario y Polit",False,"University of Valencia"+"]ES")
mapper(spain,"Gregorio Marañón",False,"Complutense University of Madrid"+"]ES")
mapper(spain,"Hospitalario Universitario A Coruña",False,"University of La Coruña"+"]ES")
mapper(spain,"INCLIVA",False,"University of Valencia"+"]ES")
mapper(spain,"Hospital Universitario Puerta de Hierro",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"Autonomous University of Madrid",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"University Autonoma of Madrid",False,"Autonomous University of Madrid"+"]ES")
mapper(spain,"12 de Octubre",False,"Complutense University of Madrid"+"]ES")
mapper(spain,"University of Seville",False,"University of Seville"+"]ES")
mapper(spain,"Hospital del Mar",False,"Pompeu Fabra University"+"]ES")
mapper(spain,"Reina Sof",False,"University of Cordoba"+"]ES")
mapper(spain,"Instituto de Salud Carlos III",False,"Instituto de Salud Carlos III"+"]ES")
mapper(spain,"Barcelona University",False,"University of Barcelona"+"]ES")
mapper(spain,"Hospital Clìnic de Barcelona",False,"University of Barcelona"+"]ES")
mapper(spain,"TransplantChild ERN",False,"TransplantChild ERN"+"]ES")
mapper(spain,"Genomic Systems",False,"Genomic Systems Inc"+"]ES")
mapper(spain,"Ramón y Cajal",False,"University of Alcalá"+"]ES")
mapper(spain,"Roman y Cajal",False,"University of Alcalá"+"]ES")
mapper(spain,"Virgen de la Arrixaca",False,"University of Murcia"+"]ES")
mapper(spain,"Santiago de Compostela",False,"University of Santiago de Compostela"+"]ES")
mapper(spain,"University Hospital of Getafe",False,"European University of Madrid"+"]ES")
mapper(spain,"Centro de Investigación Príncipe Felipe",False,"Centro de Investigación Príncipe Felipe"+"]ES")
mapper(spain,"INIA",False,"INIA"+"]ES")
mapper(spain,"Laboratorio de Refèrencia de Catalunya",False,"Laboratorio de Refèrencia de Catalunya"+"]ES")
mapper(spain,"Hospital Universitario de Cruces",False,"University of the Basque Country"+"]ES")
mapper(spain,"IDIVAL",False,"IDIVAL"+"]ES")
mapper(spain,"IdISBa",False,"University of the Balearic Islands"+"]ES")
mapper(spain,"Centro de Investigación Biomédica en Red en Enfermedades Cardiovasculares",False,"Instituto de Salud Carlos III"+"]ES")
mapper(spain,"CIBERCV",False,"Instituto de Salud Carlos III"+"]ES")
mapper(spain,"Fresenius",False,"Fresenius Inc"+"]SE")
mapper(spain,"Organització Catalana de Trasplantaments",False,"Organització Catalana de Trasplantaments"+"]ES")
mapper(spain,"Coordinación Autonómica de Trasplantes de Andalucía",False,"Coordinación Autonómica de Trasplantes de Andalucía"+"]ES")
# Out:
# /var/folders/f9/x6_f23z13z1dpfwmrmvqkhbm0000gn/T/ipykernel_50075/619395349.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent

# %%
test = pd.concat([usa,canada,france,uk,germany,brussels,nether,australia,italy,spain,india,japan,israel,sweden,brazil,taiwan,denmark,korea,swiss,austria,nz,mex,pol,mid,argen,sing,czech,irish,the_rest])

# %%
len(test)
# Out:
# 4090

# %%
test.to_csv("MAPPINGS.csv")

# %%
import pandas as pd
second_pass = pd.read_csv("parent_orgs_extracted.csv")

# %%
stragglers = second_pass[second_pass['PARENT_ORGS'] == "set()"]

# %%
import re
list_of_stragglers = []
for aff in stragglers['Affiliations']:
    try:
        list_of_stragglers.append(re.split(r'////|; ',aff))
    except:
        pass

result = list(set().union(*list_of_stragglers))
len(result)
# Out:
# 0

# %%
result = pd.DataFrame({'Unnamed: 0': result})

# %%
result
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
result['PARENT'] = ''
for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
    mapper(result, uni, False, test)
mapper(result, "Second Military Medical", False, "Naval Medical University"+"]CN")
mapper(result, "Naval Medical University", False, "Naval Medical University"+"]CN")
mapper(result, "Capital Medical University", False, "Capital Medical University"+"]CN")
mapper(result, "Zhengzhou university", False, "Zhengzhou University"+"]CN")
mapper(result, "Sun Yat-Sen university", False, "Sun Yat-Sen University"+"]CN")
mapper(result, "Southern Medical University",False, "Southern Medical University"+"]CN")
mapper(result, "Peking Union Medical College", False, "Peking Union Medical College"+"]CN")
mapper(result, "Shanghai Jiao Tong University", False, "Shanghai Jiao Tong University"+"]CN")
mapper(result, 'Guangzhou medical university', False, "Guangzhou Medical University"+"]CN")
mapper(result, 'Guangdong medical university', False, "Guangdong Medical University"+"]CN")
mapper(result, "Guangdong Academy of Medical Sciences", False, "GDAS"+"]CN")
mapper(result, "Guangdong provincial people's Hospital", False , "GDAS"+"]CN")
mapper(result, "China Medical University", False , "China Medical University"+"]CN")
mapper(result, 'Shandong first medical university', False, "Shandong University"+"]CN")
mapper(result, 'Beijing University of Chinese Medicine', False, "Beijing University of Chinese Medicine"+"]CN")
mapper(result, "Army Medical University", False, "Army Medical University"+"]CN")
mapper(result, "Zhejiang Chinese Medical University", False, "Zhejiang Chinese Medical University"+"]CN")
mapper(result, "Zhejiang Medical University", False, "Zhejiang University"+"]CN")
mapper(result, "Tung Wah Hospital", False, "University of Hong Kong"+"]HK")
mapper(result, "Chinese Academy of Medical Sciences", False, "Peking Union Medical College"+"]CN")
mapper(result, "Tuen Mun Hospital", False, "Hospital Authority"+"]CN")
mapper(result, "Hospital Authority", False, "Hospital Authority"+"]CN")
mapper(result, "Hong Kong children's", False, "University of Hong Kong"+"]HK")
mapper(result, "huizhou municipal central hospital",False,'Huizhou Municipal Central Hospital'+"]CN")
mapper(result, "Kailuan General", False, "Kailuan General Hospital"+"]CN")
mapper(result, "Hunan Clinical Research Center of Ophthalmic Disease", False, "Hunan Clinical Research Center of Ophthalmic Disease"+"]CN")
mapper(result,"Jiangxi Provincial Children's", False, "Jiangxi Provincial Children's Hospital"+"]CN")
mapper(result, "beijing municipal key laboratory of clinical epidemiology", False, "Capital Medical University"+"]CN")
mapper(result, "first people's hospital of foshan", False, "Pyrexar Medical"+"]CN")
mapper(result, "Huazhong University of Science & Technology", False, "Huazhong University of Science and Technology"+"]CN")
mapper(result, "Shenzhen Maternity & Child Healthcare Hospital", False,'Shenzhen Maternity and Child Healthcare Hospital'+"]CN")
mapper(result, 'Hong Kong Science and Technology Park',False,'Hong Kong Science and Technology Park'+"]HK")
mapper(result, 'Queen Mary Hospital',False,'University of Hong Kong'+"]HK")
mapper(result, "Key Laboratory of Chronic Kidney Disease Prevention and Treatment", False, "Peking University"+"]CN")
mapper(result, "Mengniu", False, "Mengniu Ltd"+"]CN")
mapper(result, "BGI", False, "BGI Ltd"+"]CN")
mapper(result, "Beijing institute of biotech", False, "Beijing North Institute of Biotechnology Ltd"+"]CN")
mapper(result, "Maoming People's Hospital", False, "Maoming People's Hospital"+"]CN")
mapper(result, "Liver Disease Prevention and Treatment Research Foundation", False, "Liver Disease Prevention and Treatment Research Foundation"+"]CN")
mapper(result, "DHC", False, "DHC Ltd"+"]CN")
mapper(result, "Renji Hospital", False, "Shanghai Jiao Tong University"+"]CN")
mapper(result, "Three Gorges University", False, "Three Gorges University"+"]CN")
mapper(result, "GlaxoSmithKline", False, "GlaxoSmithKline Inc"+"]GB")
mapper(result, 'KingMed',False,'KingMed Diagnostic Ltd'+"]CN")
mapper(result, 'Beijing Haidian', False, "Peking University"+"]CN")
mapper(result, "Zhejiang provincial people's hospital",False,"Hangzhou Medical College"+"]CN")
mapper(result, "Ningxia Medical University",False,"Ningxia Medical University"+"]CN")
mapper(result, "Sichuan Provincial People's Hospital",False,"University of Electronic Science and Technology of China"+"]CN")
mapper(result, "Shenzhen Zaozhidao Technology",False, "Zaozhidao Technology Ltd"+"]CN")
mapper(result,"Prince of Wales Hospital", False, "Hospital Authority"+"]CN")
mapper(result,"The People's Hospital of Guangxi Zhuang",False, "GXAS"+"]CN")
mapper(result,"Biomedical Imaging Center",False,"Biomedical Imaging Center"+"]CN")
mapper(result,"Beijing Friendship Hospital",False,"Capital Medical University"+"]CN")
mapper(result,"Chinese PLA General",False,"PLA"+"]CN")
mapper(result,"Guangzhou National Lab",False, "Guangzhou National Laboratory"+"]CN")
mapper(result,"Fourth Military Medical",False, "Fourth Military Medical University"+"]CN")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 3
#       1 result['PARENT'] = ''
#       2 for uni, test in zip(abrev_uni['Uni'],abrev_uni['TEST']):
# ----> 3     mapper(result, uni, False, test)
#       4 mapper(result, "Second Military Medical", False, "Naval Medical University"+"]CN")
#       5 mapper(result, "Naval Medical University", False, "Naval Medical University"+"]CN")
#
# Cell In[44], line 2, in mapper(df, search, case, parent)
#       1 def mapper(df, search, case, parent):
# ----> 2     df.loc[df['Unnamed: 0'].str.contains(search, case=case), 'PARENT'] = parent
#
# File ~/miniforge3/envs/islp/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
# ...

# %%
mapper(result,"Tel-Aviv Uni",False,"Tel-Aviv University"+"]IL")
mapper(result,"University Medical Center Hamburg",False,"University of Hamburg"+"]DE")
mapper(result,"Hannover Medical",False,"Hannover Medical School"+"]DE")
mapper(result,"Galilee Medical",False,"Galilee Medical Center"+"]IL")
mapper(result,"Technion",False,"Technion-Israel Institute of Technology"+"]IL")
mapper(result,"Rambam Health",False,"Technion-Israel Institute of Technology"+"]IL")
mapper(result,"Sheba Medical",False,"Tel-Aviv University"+"]IL")
mapper(result,"Hans-Knöll",False,"Hans Knoll Institute"+"]DE")
mapper(result,"Baruch Padeh",False,"Bar-Ilan University"+"]IL")
mapper(result,"Hospital of Essen",False,"University of Duisburg-Essen"+"]DE")
mapper(result,"Hospital Essen",False,"University of Duisburg-Essen"+"]DE")
mapper(result,"University of Cologne",False,"University of Cologne"+"]DE")
mapper(result,"University of Freiburg",False,"University of Freiburg"+"]DE")
mapper(result,"Carmel Medical",False,"Clalit Health Co"+"]IL")
mapper(result,"University of Regensburg",False,"University of Regensburg"+"]DE")
mapper(result,"Justus-Liebig-University",False,"University of Giessen"+"]DE")
mapper(result,"Mayanei HaYeshua Medical Center",False,"Mayanei HaYeshua Medical Center"+"]IL")
mapper(result,"Ziv Medical Center",False,"Bar-Ilan University"+"]IL")
mapper(result,"Bnai-Zion Medical",False,"Technion-Israel Institute of Technology"+"]IL")
mapper(result,"Vivantes",False,"Vivantes Group Co"+"]DE")
mapper(result,"University Medical Center Regensburg",False,"University of Regensburg"+"]DE")
mapper(result,"Assuta",False,"Assuta Co"+"]IL")
mapper(result,"Hebrew University",False,"Hebrew University"+"]IL")
mapper(result,"Schneider Children's Medical",False,"Tel-Aviv University"+"]IL")
mapper(result,"Israel Center for Disease Control",False,"ICDC"+"]IL")
mapper(result,"University Clinics Freiburg",False,"University of Freiburg"+"]DE")

# %%
result.to_csv("STRAGGLE_MAPS.csv")

# %% [markdown]
# # Dept Extraction

# %%
extraction = pd.read_csv('extraction.csv')

# %%
import re
extraction['Dept'] = ""

#pattern = r'\b(?:Department|Section|Division)s? of ([\w\s&]+?)(?=,|;|\.| and | & |$)'
pattern = r'\b(?:Department|Section|Division|Departments|Sections|Divisions) of ([\w\s&]+?)(?=,|;|\.|\b(?: and ))'

# %%
extraction['Dept'] = extraction['Unnamed: 0'].apply(lambda x: dept_regex.findall(x))
