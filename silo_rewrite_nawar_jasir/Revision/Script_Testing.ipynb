# %%
from Bio import Entrez
import pandas as pd
from silo_utils_revision import *
PMID_TO_CHECK = 37055195

# %%
test_article = retrieve_summary(37094330)
test_fetch = retrieve_data(int(test_article[0]['ArticleIds']['pmc'].replace("PMC","")),db="pmc")

# %%
test_article = retrieve_data(37094330)

# %%
test_article = retrieve_full_text(10356144)

# %%
test_article
# Out:
# b'<?xml version="1.0" ?>\n<!DOCTYPE pmc-articleset PUBLIC "-//NLM//DTD ARTICLE SET 2.0//EN" "https://dtd.nlm.nih.gov/ncbi/pmc/articleset/nlm-articleset-2.0.dtd">\n<pmc-articleset><article xmlns:mml="http://www.w3.org/1998/Math/MathML" xmlns:xlink="http://www.w3.org/1999/xlink" dtd-version="1.3" xml:lang="en" article-type="research-article">\n  <!--The publisher of this article does not allow downloading of the full text in XML form.-->\n  <processing-meta base-tagset="archiving" mathml-version="3.0" table-model="xhtml" tagset-family="jats">\n    <restricted-by>pmc</restricted-by>\n  </processing-meta>\n  <front>\n    <journal-meta>\n      <journal-id journal-id-type="nlm-ta">Clin J Am Soc Nephrol</journal-id>\n      <journal-id journal-id-type="iso-abbrev">Clin J Am Soc Nephrol</journal-id>\n      <journal-id journal-id-type="coden">CJASN</journal-id>\n      <journal-id journal-id-type="publisher-id">CJASN</journal-id>\n      <journal-title-group>\n        <journal-title>Clinical Jou
# ...

# %%
test_article[0]['front'].keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test_article[0]['front'].keys()
#
# TypeError: 'int' object is not subscriptable

# %%
test_article[0]['front']['article-meta']
# Out:
# {'article-id': [StringElement('37094330', attributes={'pub-id-type': 'pmid'}), StringElement('10356144', attributes={'pub-id-type': 'pmc'}), StringElement('CJASN-2023-000595', attributes={'pub-id-type': 'publisher-id'}), StringElement('10.2215/CJN.0000000000000182', attributes={'pub-id-type': 'doi'}), StringElement('00010', attributes={'pub-id-type': 'art-access-id'})], 'x': [], 'pub-date': [ListElement(['7', '2023'], attributes={'pub-type': 'ppub'}), ListElement(['21', '4', '2023'], attributes={'pub-type': 'epub'})], 'aff': [], 'product': [], 'issue-id': [], 'funding-group': [], 'contrib-group': [[ListElement([StringElement('https://orcid.org/0000-0002-4138-101X', attributes={'contrib-id-type': 'orcid', 'authenticated': 'false'}), {'surname': 'Werion', 'given-names': 'Alexis'}, StringElement('\n<sup>1</sup>\n', attributes={'rid': 'aff1', 'ref-type': 'aff'}), StringElement('\n<sup>2</sup>\n', attributes={'rid': 'aff2', 'ref-type': 'aff'}), StringElement('', attributes={'vocab': 'CRed
# ...
